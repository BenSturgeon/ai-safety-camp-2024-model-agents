# %%
import heist
import helpers
import torch.distributions
import torch

import gym
import random
import numpy as np
from helpers import generate_action, load_model
import imageio
import matplotlib.pyplot as plt
import typing
import math

from procgen import ProcgenGym3Env
import struct
import typing
from typing import Tuple, Dict, Callable, List, Optional
from dataclasses import dataclass
from src.policies_impala import ImpalaCNN
from procgen_tools.procgen_wrappers import VecExtractDictObs, TransposeFrame, ScaledFloatFrame

from gym3 import ToBaselinesVecEnv
import seaborn as sns
import random

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ordered_layer_names = {
 0: 'conv_seqs',
 1: 'conv_seqs.0',
 2: 'conv_seqs.0.conv',
 3: 'conv_seqs.0.max_pool2d',
 4: 'conv_seqs.0.res_block0',
 5: 'conv_seqs.0.res_block0.conv0',
 6: 'conv_seqs.0.res_block0.conv1',
 7: 'conv_seqs.0.res_block1',
 8: 'conv_seqs.0.res_block1.conv0',
 9: 'conv_seqs.0.res_block1.conv1',
 10: 'conv_seqs.1',
 11: 'conv_seqs.1.conv',
 12: 'conv_seqs.1.max_pool2d',
 13: 'conv_seqs.1.res_block0',
 14: 'conv_seqs.1.res_block0.conv0',
 15: 'conv_seqs.1.res_block0.conv1',
 16: 'conv_seqs.1.res_block1',
 17: 'conv_seqs.1.res_block1.conv0',
 18: 'conv_seqs.1.res_block1.conv1',
 19: 'conv_seqs.2',
 20: 'conv_seqs.2.conv',
 21: 'conv_seqs.2.max_pool2d',
 22: 'conv_seqs.2.res_block0',
 23: 'conv_seqs.2.res_block0.conv0',
 24: 'conv_seqs.2.res_block0.conv1',
 25: 'conv_seqs.2.res_block1',
 26: 'conv_seqs.2.res_block1.conv0',
 27: 'conv_seqs.2.res_block1.conv1',
 28: 'hidden_fc',
 29: 'logits_fc',
 30: 'value_fc'
}

# %%
def run_gem_steering_experiment(model_path, layer_number, modification_value, num_levels=1, start_level=5, episode_timeout=200, save_gif=False):
    start_level = random.randint(1, 10000)
    venv = heist.create_venv(num=1, num_levels=num_levels, start_level=start_level)
    state = heist.state_from_venv(venv, 0)
    unchanged_obs = venv.reset()

    state_values = state.state_vals

    for ents in state_values["ents"]:
        if ents["image_type"].val== 9:
            gem_x = ents["x"].val 
            gem_y = ents["y"].val 

    state.remove_gem()

    state_bytes = state.state_bytes
    if state_bytes is not None:
        venv.env.callmethod("set_state", [state_bytes])
        modified_obs = venv.reset()

    state = heist.state_from_venv(venv, 0)

    state.set_gem_position(gem_y-.5,gem_x-.5)

    state_bytes = state.state_bytes

    if state_bytes is not None:
        venv.env.callmethod("set_state", [state_bytes])


    model = helpers.load_model(model_path=model_path)
    steering_layer_unchanged = ordered_layer_names[layer_number]
    steering_layer = helpers.rename_path(steering_layer_unchanged)

    model_activations = helpers.ModelActivations(model)
    model_activations.clear_hooks()
    output1, unmodified_activations = model_activations.run_with_cache(helpers.observation_to_rgb(unchanged_obs), [ordered_layer_names[layer_number]])
    model_activations.clear_hooks()
    output2, modified_obs_activations = model_activations.run_with_cache(helpers.observation_to_rgb(modified_obs), [ordered_layer_names[layer_number]])

    steering_vector = unmodified_activations[steering_layer][0] - modified_obs_activations[steering_layer][0]

    total_reward_steering, frames_steering, observations_steering = helpers.run_episode_with_steering_and_save_as_gif(
        venv, model, steering_vector, steering_layer=ordered_layer_names[layer_number],
        modification_value=modification_value, filepath=f'episode_steering_{episode}.gif',
        save_gif=save_gif, episode_timeout=episode_timeout
    )
    if save_gif:
        helpers.plot_single_observation(observations_steering[-1])
    state = heist.state_from_venv(venv, 0)

    state_vals = state.state_vals

    lock_positions_after = heist.get_lock_statuses(state_vals)
    print(lock_positions_after)

    return total_reward_steering, state_vals

# %%
model_path = "../model_final.pt"
modification_value = -2
total_episodes = 50
best_layer = None
best_score = 0
layer_number = 14


takes_everything_but_rewards = 0
skips_some_other_objective_along_with_rewards = 0
skips_rewards = 0
for episode in range(total_episodes):
    filepath=f'episode_steering_{episode}.gif'
    total_reward_steering, state_vals = run_gem_steering_experiment(model_path, layer_number, modification_value, save_gif=False)
    print(total_reward_steering)
    

    has_keys = False
    has_locks = False
    key_details = []
    lock_details = []

    
    KEY_COLORS = {0: 'blue', 1: 'green', 2: 'red'}

    # Loop through all entities to check if they are keys or locks
    for entity in state_vals["ents"]:
        if entity["image_type"].val == 2:  # image_type 2 for keys
            has_keys = True
            key_color = KEY_COLORS.get(entity["image_theme"].val, "Unknown")
            key_details.append({"position": (entity["x"].val, entity["y"].val), "color": key_color})
        elif entity["image_type"].val == 1:  # image_type 1 for locks
            has_locks = True
            lock_color = KEY_COLORS.get(entity["image_theme"].val, "Unknown")
            lock_details.append({"position": (entity["x"].val, entity["y"].val), "color": lock_color})

    if not has_locks:
        key_details = []
        has_keys = False

    #print("details about the key details", has_keys, key_details)
    #print("details about the lock details", has_locks, lock_details)
    #print("details about reward steering", total_reward_steering)
    if total_reward_steering == 0 and not has_keys and not has_locks:
        takes_everything_but_rewards += 1
    if total_reward_steering == 0 and (has_keys or has_locks):
        skips_some_other_objective_along_with_rewards += 1
    if total_reward_steering != 0:
        skips_rewards += 1


print(f"Takes everything but rewards but out of total episodes: {takes_everything_but_rewards}/{total_episodes}")
print(f"Skips rewards along with some other objectives of total episodes: {skips_some_other_objective_along_with_rewards}/{total_episodes}")
print(f"Skips rewards of total episodes:{skips_rewards}/{total_episodes}")
# Out:
# Warning: Buffer underflow at index 21117 with size 4, buffer length 21117. Returning default value.
# Warning: Buffer underflow at index 21117 with size 4, buffer length 21117. Returning default value.
# Warning: Buffer underflow at index 21117 with size 4, buffer length 21117. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# [{'x': StateValue(val=4.5, idx=13784), 'y': StateValue(val=1.5, idx=13788), 'vx': StateValue(val=0.0, idx=13792), 'vy': StateValue(val=0.0, idx=13796), 'rx': StateValue(val=0.5, idx=13800), 'ry': StateValue(val=0.5, idx=13804), 'type': StateValue(val=1, idx=13808), 'image_type': StateValue(val=1, idx=13812), 'image_theme': StateValue(val=1, idx=13816), 'render_z': StateValue(val=0, idx=13820), 'will_erase': StateValue(val=0, idx=13824), 'collides_with_entities': StateValue(val=0, idx=13828), 'collision_margin': StateValue(val=0.0, idx=13832), 'rotation': StateValue(val=0.0, idx=13836), 'vrot': StateValue(val=0.0, idx=13840), 'is_reflected': StateValue(val=0, idx=13844), 'fire_time': StateValue(val=-1, idx=13848), 'spawn_time': StateValue(val=-1, idx=13852), 'life_time': StateValue(val=0, idx=13856), 'expire_time': StateValue(val=-1, idx=13860), 'use_abs_coords': StateValue(val=0, idx=13864), 'friction': StateValue(val=1.0, idx=13868), 'smart_step': StateValue(val=0, idx=13872), 'avoids_collisions': StateValue(val=0, idx=13876), 'auto_erase': StateValue(val=1, idx=13880), 'alpha': StateValue(val=1.0, idx=13884), 'health': StateValue(val=1.0, idx=13888), 'theta': StateValue(val=-100.0, idx=13892), 'grow_rate': StateValue(val=1.0, idx=13896), 'alpha_decay': StateValue(val=1.0, idx=13900), 'climber_spawn_x': StateValue(val=0.0, idx=13904)}, {'x': StateValue(val=6.5, idx=14032), 'y': StateValue(val=3.5, idx=14036), 'vx': StateValue(val=0.0, idx=14040), 'vy': StateValue(val=0.0, idx=14044), 'rx': StateValue(val=0.5, idx=14048), 'ry': StateValue(val=0.5, idx=14052), 'type': StateValue(val=1, idx=14056), 'image_type': StateValue(val=1, idx=14060), 'image_theme': StateValue(val=0, idx=14064), 'render_z': StateValue(val=0, idx=14068), 'will_erase': StateValue(val=0, idx=14072), 'collides_with_entities': StateValue(val=0, idx=14076), 'collision_margin': StateValue(val=0.0, idx=14080), 'rotation': StateValue(val=0.0, idx=14084), 'vrot': StateValue(val=0.0, idx=14088), 'is_reflected': StateValue(val=0, idx=14092), 'fire_time': StateValue(val=-1, idx=14096), 'spawn_time': StateValue(val=-1, idx=14100), 'life_time': StateValue(val=0, idx=14104), 'expire_time': StateValue(val=-1, idx=14108), 'use_abs_coords': StateValue(val=0, idx=14112), 'friction': StateValue(val=1.0, idx=14116), 'smart_step': StateValue(val=0, idx=14120), 'avoids_collisions': StateValue(val=0, idx=14124), 'auto_erase': StateValue(val=1, idx=14128), 'alpha': StateValue(val=1.0, idx=14132), 'health': StateValue(val=1.0, idx=14136), 'theta': StateValue(val=-100.0, idx=14140), 'grow_rate': StateValue(val=1.0, idx=14144), 'alpha_decay': StateValue(val=1.0, idx=14148), 'climber_spawn_x': StateValue(val=0.0, idx=14152)}]
# [10.]
# details about the key details True [{'position': (3.5834836959838867, 5.397345542907715), 'color': 'blue'}, {'position': (8.589616775512695, 1.4942939281463623), 'color': 'green'}, {'position': (0.9624999761581421, 0.022499999031424522), 'color': 'blue'}, {'position': (0.9024999737739563, 0.022499999031424522), 'color': 'green'}]
# details about the lock details True [{'position': (4.5, 1.5), 'color': 'green'}, {'position': (6.5, 3.5), 'color': 'blue'}]
# details about reward steering [10.]
# Warning: Buffer underflow at index 21231 with size 4, buffer length 21231. Returning default value.
# Warning: Buffer underflow at index 21231 with size 4, buffer length 21231. Returning default value.
# Warning: Buffer underflow at index 21231 with size 4, buffer length 21231. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21354 with size 4, buffer length 21354. Returning default value.
# Warning: Buffer underflow at index 21354 with size 4, buffer length 21354. Returning default value.
# Warning: Buffer underflow at index 21354 with size 4, buffer length 21354. Returning default value.
# [{'x': StateValue(val=2.5, idx=13688), 'y': StateValue(val=6.5, idx=13692), 'vx': StateValue(val=0.0, idx=13696), 'vy': StateValue(val=0.0, idx=13700), 'rx': StateValue(val=0.5, idx=13704), 'ry': StateValue(val=0.5, idx=13708), 'type': StateValue(val=1, idx=13712), 'image_type': StateValue(val=1, idx=13716), 'image_theme': StateValue(val=1, idx=13720), 'render_z': StateValue(val=0, idx=13724), 'will_erase': StateValue(val=0, idx=13728), 'collides_with_entities': StateValue(val=0, idx=13732), 'collision_margin': StateValue(val=0.0, idx=13736), 'rotation': StateValue(val=0.0, idx=13740), 'vrot': StateValue(val=0.0, idx=13744), 'is_reflected': StateValue(val=0, idx=13748), 'fire_time': StateValue(val=-1, idx=13752), 'spawn_time': StateValue(val=-1, idx=13756), 'life_time': StateValue(val=200, idx=13760), 'expire_time': StateValue(val=-1, idx=13764), 'use_abs_coords': StateValue(val=0, idx=13768), 'friction': StateValue(val=1.0, idx=13772), 'smart_step': StateValue(val=0, idx=13776), 'avoids_collisions': StateValue(val=0, idx=13780), 'auto_erase': StateValue(val=1, idx=13784), 'alpha': StateValue(val=1.0, idx=13788), 'health': StateValue(val=1.0, idx=13792), 'theta': StateValue(val=-100.0, idx=13796), 'grow_rate': StateValue(val=1.0, idx=13800), 'alpha_decay': StateValue(val=1.0, idx=13804), 'climber_spawn_x': StateValue(val=0.0, idx=13808)}]
# [0.]
# details about the key details True [{'position': (0.9624999761581421, 0.022499999031424522), 'color': 'blue'}, {'position': (0.9024999737739563, 0.022499999031424522), 'color': 'green'}]
# details about the lock details True [{'position': (2.5, 6.5), 'color': 'green'}]
# details about reward steering [0.]
# Warning: Buffer underflow at index 21102 with size 4, buffer length 21102. Returning default value.
# Warning: Buffer underflow at index 21102 with size 4, buffer length 21102. Returning default value.
# Warning: Buffer underflow at index 21102 with size 4, buffer length 21102. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# []
# [10.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [10.]
# Warning: Buffer underflow at index 21369 with size 4, buffer length 21369. Returning default value.
# Warning: Buffer underflow at index 21369 with size 4, buffer length 21369. Returning default value.
# Warning: Buffer underflow at index 21369 with size 4, buffer length 21369. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21111 with size 4, buffer length 21111. Returning default value.
# Warning: Buffer underflow at index 21111 with size 4, buffer length 21111. Returning default value.
# Warning: Buffer underflow at index 21111 with size 4, buffer length 21111. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# []
# [10.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [10.]
# Warning: Buffer underflow at index 21239 with size 4, buffer length 21239. Returning default value.
# Warning: Buffer underflow at index 21239 with size 4, buffer length 21239. Returning default value.
# Warning: Buffer underflow at index 21239 with size 4, buffer length 21239. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21224 with size 4, buffer length 21224. Returning default value.
# Warning: Buffer underflow at index 21224 with size 4, buffer length 21224. Returning default value.
# Warning: Buffer underflow at index 21224 with size 4, buffer length 21224. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21112 with size 4, buffer length 21112. Returning default value.
# Warning: Buffer underflow at index 21112 with size 4, buffer length 21112. Returning default value.
# Warning: Buffer underflow at index 21112 with size 4, buffer length 21112. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# []
# [10.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [10.]
# Warning: Buffer underflow at index 21385 with size 4, buffer length 21385. Returning default value.
# Warning: Buffer underflow at index 21385 with size 4, buffer length 21385. Returning default value.
# Warning: Buffer underflow at index 21385 with size 4, buffer length 21385. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21382 with size 4, buffer length 21382. Returning default value.
# Warning: Buffer underflow at index 21382 with size 4, buffer length 21382. Returning default value.
# Warning: Buffer underflow at index 21382 with size 4, buffer length 21382. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21138 with size 4, buffer length 21138. Returning default value.
# Warning: Buffer underflow at index 21138 with size 4, buffer length 21138. Returning default value.
# Warning: Buffer underflow at index 21138 with size 4, buffer length 21138. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# [{'x': StateValue(val=0.5, idx=13738), 'y': StateValue(val=6.5, idx=13742), 'vx': StateValue(val=0.0, idx=13746), 'vy': StateValue(val=0.0, idx=13750), 'rx': StateValue(val=0.5, idx=13754), 'ry': StateValue(val=0.5, idx=13758), 'type': StateValue(val=1, idx=13762), 'image_type': StateValue(val=1, idx=13766), 'image_theme': StateValue(val=2, idx=13770), 'render_z': StateValue(val=0, idx=13774), 'will_erase': StateValue(val=0, idx=13778), 'collides_with_entities': StateValue(val=0, idx=13782), 'collision_margin': StateValue(val=0.0, idx=13786), 'rotation': StateValue(val=0.0, idx=13790), 'vrot': StateValue(val=0.0, idx=13794), 'is_reflected': StateValue(val=0, idx=13798), 'fire_time': StateValue(val=-1, idx=13802), 'spawn_time': StateValue(val=-1, idx=13806), 'life_time': StateValue(val=0, idx=13810), 'expire_time': StateValue(val=-1, idx=13814), 'use_abs_coords': StateValue(val=0, idx=13818), 'friction': StateValue(val=1.0, idx=13822), 'smart_step': StateValue(val=0, idx=13826), 'avoids_collisions': StateValue(val=0, idx=13830), 'auto_erase': StateValue(val=1, idx=13834), 'alpha': StateValue(val=1.0, idx=13838), 'health': StateValue(val=1.0, idx=13842), 'theta': StateValue(val=-100.0, idx=13846), 'grow_rate': StateValue(val=1.0, idx=13850), 'alpha_decay': StateValue(val=1.0, idx=13854), 'climber_spawn_x': StateValue(val=0.0, idx=13858)}, {'x': StateValue(val=2.5, idx=14110), 'y': StateValue(val=0.5, idx=14114), 'vx': StateValue(val=0.0, idx=14118), 'vy': StateValue(val=0.0, idx=14122), 'rx': StateValue(val=0.5, idx=14126), 'ry': StateValue(val=0.5, idx=14130), 'type': StateValue(val=1, idx=14134), 'image_type': StateValue(val=1, idx=14138), 'image_theme': StateValue(val=1, idx=14142), 'render_z': StateValue(val=0, idx=14146), 'will_erase': StateValue(val=0, idx=14150), 'collides_with_entities': StateValue(val=0, idx=14154), 'collision_margin': StateValue(val=0.0, idx=14158), 'rotation': StateValue(val=0.0, idx=14162), 'vrot': StateValue(val=0.0, idx=14166), 'is_reflected': StateValue(val=0, idx=14170), 'fire_time': StateValue(val=-1, idx=14174), 'spawn_time': StateValue(val=-1, idx=14178), 'life_time': StateValue(val=0, idx=14182), 'expire_time': StateValue(val=-1, idx=14186), 'use_abs_coords': StateValue(val=0, idx=14190), 'friction': StateValue(val=1.0, idx=14194), 'smart_step': StateValue(val=0, idx=14198), 'avoids_collisions': StateValue(val=0, idx=14202), 'auto_erase': StateValue(val=1, idx=14206), 'alpha': StateValue(val=1.0, idx=14210), 'health': StateValue(val=1.0, idx=14214), 'theta': StateValue(val=-100.0, idx=14218), 'grow_rate': StateValue(val=1.0, idx=14222), 'alpha_decay': StateValue(val=1.0, idx=14226), 'climber_spawn_x': StateValue(val=0.0, idx=14230)}, {'x': StateValue(val=2.5, idx=14234), 'y': StateValue(val=4.5, idx=14238), 'vx': StateValue(val=0.0, idx=14242), 'vy': StateValue(val=0.0, idx=14246), 'rx': StateValue(val=0.5, idx=14250), 'ry': StateValue(val=0.5, idx=14254), 'type': StateValue(val=1, idx=14258), 'image_type': StateValue(val=1, idx=14262), 'image_theme': StateValue(val=0, idx=14266), 'render_z': StateValue(val=0, idx=14270), 'will_erase': StateValue(val=0, idx=14274), 'collides_with_entities': StateValue(val=0, idx=14278), 'collision_margin': StateValue(val=0.0, idx=14282), 'rotation': StateValue(val=0.0, idx=14286), 'vrot': StateValue(val=0.0, idx=14290), 'is_reflected': StateValue(val=0, idx=14294), 'fire_time': StateValue(val=-1, idx=14298), 'spawn_time': StateValue(val=-1, idx=14302), 'life_time': StateValue(val=0, idx=14306), 'expire_time': StateValue(val=-1, idx=14310), 'use_abs_coords': StateValue(val=0, idx=14314), 'friction': StateValue(val=1.0, idx=14318), 'smart_step': StateValue(val=0, idx=14322), 'avoids_collisions': StateValue(val=0, idx=14326), 'auto_erase': StateValue(val=1, idx=14330), 'alpha': StateValue(val=1.0, idx=14334), 'health': StateValue(val=1.0, idx=14338), 'theta': StateValue(val=-100.0, idx=14342), 'grow_rate': StateValue(val=1.0, idx=14346), 'alpha_decay': StateValu ...
# [10.]
# details about the key details True [{'position': (1.561244249343872, 0.40766987204551697), 'color': 'red'}, {'position': (3.536860704421997, 2.4663991928100586), 'color': 'green'}, {'position': (3.530519962310791, 8.591201782226562), 'color': 'blue'}, {'position': (0.9624999761581421, 0.022499999031424522), 'color': 'blue'}, {'position': (0.9024999737739563, 0.022499999031424522), 'color': 'green'}, {'position': (0.8425000309944153, 0.022499999031424522), 'color': 'red'}]
# details about the lock details True [{'position': (0.5, 6.5), 'color': 'red'}, {'position': (2.5, 0.5), 'color': 'green'}, {'position': (2.5, 4.5), 'color': 'blue'}]
# details about reward steering [10.]
# Warning: Buffer underflow at index 21381 with size 4, buffer length 21381. Returning default value.
# Warning: Buffer underflow at index 21381 with size 4, buffer length 21381. Returning default value.
# Warning: Buffer underflow at index 21381 with size 4, buffer length 21381. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21135 with size 4, buffer length 21135. Returning default value.
# Warning: Buffer underflow at index 21135 with size 4, buffer length 21135. Returning default value.
# Warning: Buffer underflow at index 21135 with size 4, buffer length 21135. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21236 with size 4, buffer length 21236. Returning default value.
# Warning: Buffer underflow at index 21236 with size 4, buffer length 21236. Returning default value.
# Warning: Buffer underflow at index 21236 with size 4, buffer length 21236. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21252 with size 4, buffer length 21252. Returning default value.
# Warning: Buffer underflow at index 21252 with size 4, buffer length 21252. Returning default value.
# Warning: Buffer underflow at index 21252 with size 4, buffer length 21252. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# []
# [10.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [10.]
# Warning: Buffer underflow at index 21089 with size 4, buffer length 21089. Returning default value.
# Warning: Buffer underflow at index 21089 with size 4, buffer length 21089. Returning default value.
# Warning: Buffer underflow at index 21089 with size 4, buffer length 21089. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21251 with size 4, buffer length 21251. Returning default value.
# Warning: Buffer underflow at index 21251 with size 4, buffer length 21251. Returning default value.
# Warning: Buffer underflow at index 21251 with size 4, buffer length 21251. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21089 with size 4, buffer length 21089. Returning default value.
# Warning: Buffer underflow at index 21089 with size 4, buffer length 21089. Returning default value.
# Warning: Buffer underflow at index 21089 with size 4, buffer length 21089. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21382 with size 4, buffer length 21382. Returning default value.
# Warning: Buffer underflow at index 21382 with size 4, buffer length 21382. Returning default value.
# Warning: Buffer underflow at index 21382 with size 4, buffer length 21382. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21370 with size 4, buffer length 21370. Returning default value.
# Warning: Buffer underflow at index 21370 with size 4, buffer length 21370. Returning default value.
# Warning: Buffer underflow at index 21370 with size 4, buffer length 21370. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21121 with size 4, buffer length 21121. Returning default value.
# Warning: Buffer underflow at index 21121 with size 4, buffer length 21121. Returning default value.
# Warning: Buffer underflow at index 21121 with size 4, buffer length 21121. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21264 with size 4, buffer length 21264. Returning default value.
# Warning: Buffer underflow at index 21264 with size 4, buffer length 21264. Returning default value.
# Warning: Buffer underflow at index 21264 with size 4, buffer length 21264. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21122 with size 4, buffer length 21122. Returning default value.
# Warning: Buffer underflow at index 21122 with size 4, buffer length 21122. Returning default value.
# Warning: Buffer underflow at index 21122 with size 4, buffer length 21122. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# [{'x': StateValue(val=6.5, idx=13842), 'y': StateValue(val=1.5, idx=13846), 'vx': StateValue(val=0.0, idx=13850), 'vy': StateValue(val=0.0, idx=13854), 'rx': StateValue(val=0.5, idx=13858), 'ry': StateValue(val=0.5, idx=13862), 'type': StateValue(val=1, idx=13866), 'image_type': StateValue(val=1, idx=13870), 'image_theme': StateValue(val=0, idx=13874), 'render_z': StateValue(val=0, idx=13878), 'will_erase': StateValue(val=0, idx=13882), 'collides_with_entities': StateValue(val=0, idx=13886), 'collision_margin': StateValue(val=0.0, idx=13890), 'rotation': StateValue(val=0.0, idx=13894), 'vrot': StateValue(val=0.0, idx=13898), 'is_reflected': StateValue(val=0, idx=13902), 'fire_time': StateValue(val=-1, idx=13906), 'spawn_time': StateValue(val=-1, idx=13910), 'life_time': StateValue(val=0, idx=13914), 'expire_time': StateValue(val=-1, idx=13918), 'use_abs_coords': StateValue(val=0, idx=13922), 'friction': StateValue(val=1.0, idx=13926), 'smart_step': StateValue(val=0, idx=13930), 'avoids_collisions': StateValue(val=0, idx=13934), 'auto_erase': StateValue(val=1, idx=13938), 'alpha': StateValue(val=1.0, idx=13942), 'health': StateValue(val=1.0, idx=13946), 'theta': StateValue(val=-100.0, idx=13950), 'grow_rate': StateValue(val=1.0, idx=13954), 'alpha_decay': StateValue(val=1.0, idx=13958), 'climber_spawn_x': StateValue(val=0.0, idx=13962)}]
# [10.]
# details about the key details True [{'position': (8.4235258102417, 5.530170440673828), 'color': 'blue'}, {'position': (0.9624999761581421, 0.022499999031424522), 'color': 'blue'}]
# details about the lock details True [{'position': (6.5, 1.5), 'color': 'blue'}]
# details about reward steering [10.]
# Warning: Buffer underflow at index 21225 with size 4, buffer length 21225. Returning default value.
# Warning: Buffer underflow at index 21225 with size 4, buffer length 21225. Returning default value.
# Warning: Buffer underflow at index 21225 with size 4, buffer length 21225. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21251 with size 4, buffer length 21251. Returning default value.
# Warning: Buffer underflow at index 21251 with size 4, buffer length 21251. Returning default value.
# Warning: Buffer underflow at index 21251 with size 4, buffer length 21251. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21081 with size 4, buffer length 21081. Returning default value.
# Warning: Buffer underflow at index 21081 with size 4, buffer length 21081. Returning default value.
# Warning: Buffer underflow at index 21081 with size 4, buffer length 21081. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21115 with size 4, buffer length 21115. Returning default value.
# Warning: Buffer underflow at index 21115 with size 4, buffer length 21115. Returning default value.
# Warning: Buffer underflow at index 21115 with size 4, buffer length 21115. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21262 with size 4, buffer length 21262. Returning default value.
# Warning: Buffer underflow at index 21262 with size 4, buffer length 21262. Returning default value.
# Warning: Buffer underflow at index 21262 with size 4, buffer length 21262. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21388 with size 4, buffer length 21388. Returning default value.
# Warning: Buffer underflow at index 21388 with size 4, buffer length 21388. Returning default value.
# Warning: Buffer underflow at index 21388 with size 4, buffer length 21388. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21196 with size 4, buffer length 21196. Returning default value.
# Warning: Buffer underflow at index 21196 with size 4, buffer length 21196. Returning default value.
# Warning: Buffer underflow at index 21196 with size 4, buffer length 21196. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21117 with size 4, buffer length 21117. Returning default value.
# Warning: Buffer underflow at index 21117 with size 4, buffer length 21117. Returning default value.
# Warning: Buffer underflow at index 21117 with size 4, buffer length 21117. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# []
# [10.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [10.]
# Warning: Buffer underflow at index 21236 with size 4, buffer length 21236. Returning default value.
# Warning: Buffer underflow at index 21236 with size 4, buffer length 21236. Returning default value.
# Warning: Buffer underflow at index 21236 with size 4, buffer length 21236. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21139 with size 4, buffer length 21139. Returning default value.
# Warning: Buffer underflow at index 21139 with size 4, buffer length 21139. Returning default value.
# Warning: Buffer underflow at index 21139 with size 4, buffer length 21139. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21244 with size 4, buffer length 21244. Returning default value.
# Warning: Buffer underflow at index 21244 with size 4, buffer length 21244. Returning default value.
# Warning: Buffer underflow at index 21244 with size 4, buffer length 21244. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21244 with size 4, buffer length 21244. Returning default value.
# Warning: Buffer underflow at index 21244 with size 4, buffer length 21244. Returning default value.
# Warning: Buffer underflow at index 21244 with size 4, buffer length 21244. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# Warning: Buffer underflow at index 21249 with size 4, buffer length 21249. Returning default value.
# Warning: Buffer underflow at index 21249 with size 4, buffer length 21249. Returning default value.
# Warning: Buffer underflow at index 21249 with size 4, buffer length 21249. Returning default value.
# []
# [0.]
# details about the key details False []
# details about the lock details False []
# details about reward steering [0.]
# [{'x': StateValue(val=2.5, idx=13836), 'y': StateValue(val=5.5, idx=13840), 'vx': StateValue(val=0.0, idx=13844), 'vy': StateValue(val=0.0, idx=13848), 'rx': StateValue(val=0.5, idx=13852), 'ry': StateValue(val=0.5, idx=13856), 'type': StateValue(val=1, idx=13860), 'image_type': StateValue(val=1, idx=13864), 'image_theme': StateValue(val=0, idx=13868), 'render_z': StateValue(val=0, idx=13872), 'will_erase': StateValue(val=0, idx=13876), 'collides_with_entities': StateValue(val=0, idx=13880), 'collision_margin': StateValue(val=0.0, idx=13884), 'rotation': StateValue(val=0.0, idx=13888), 'vrot': StateValue(val=0.0, idx=13892), 'is_reflected': StateValue(val=0, idx=13896), 'fire_time': StateValue(val=-1, idx=13900), 'spawn_time': StateValue(val=-1, idx=13904), 'life_time': StateValue(val=0, idx=13908), 'expire_time': StateValue(val=-1, idx=13912), 'use_abs_coords': StateValue(val=0, idx=13916), 'friction': StateValue(val=1.0, idx=13920), 'smart_step': StateValue(val=0, idx=13924), 'avoids_collisions': StateValue(val=0, idx=13928), 'auto_erase': StateValue(val=1, idx=13932), 'alpha': StateValue(val=1.0, idx=13936), 'health': StateValue(val=1.0, idx=13940), 'theta': StateValue(val=-100.0, idx=13944), 'grow_rate': StateValue(val=1.0, idx=13948), 'alpha_decay': StateValue(val=1.0, idx=13952), 'climber_spawn_x': StateValue(val=0.0, idx=13956)}]
# [10.]
# details about the key details True [{'position': (0.593981921672821, 4.586709022521973), 'color': 'blue'}, {'position': (0.9624999761581421, 0.022499999031424522), 'color': 'blue'}]
# details about the lock details True [{'position': (2.5, 5.5), 'color': 'blue'}]
# details about reward steering [10.]
# Takes everything but rewards but out of total episodes: 40/50
# Skips rewards along with some other objectives of total episodes: 1/50
# Skips rewards of total episodes:9/50

# %%
def experiment_comparison(model_path, total_episodes, modification_values):
    results = {}
    KEY_COLORS = {0: 'blue', 1: 'green', 2: 'red'}

    # Iterate through modification values
    for modification_value in modification_values:
        takes_everything_but_rewards = 0
        skips_some_other_objective_along_with_rewards = 0
        takes_rewards = 0
        
        for episode in range(total_episodes):
            total_reward_steering, state_vals = run_gem_steering_experiment(model_path, layer_number, modification_value)

            has_keys = False
            has_locks = False

            # Loop through all entities to check if they are keys or locks
            for entity in state_vals["ents"]:
                if entity["image_type"].val == 2:  # image_type 2 for keys
                    has_keys = True
                elif entity["image_type"].val == 1:  # image_type 1 for locks
                    has_locks = True
            if not has_locks:
                has_keys = False  #the keys are only displayed on the image as a score

            if total_reward_steering == 0 and not has_keys and not has_locks:
                takes_everything_but_rewards += 1
            if total_reward_steering == 0 and (has_keys or has_locks):
                skips_some_other_objective_along_with_rewards += 1
            if total_reward_steering != 0:
                takes_rewards += 1

        # Store results for each modification value
        results[modification_value] = {
            "takes_everything_but_rewards": takes_everything_but_rewards,
            "skips_some_other_objective_along_with_rewards": skips_some_other_objective_along_with_rewards,
            "takes_rewards": takes_rewards
        }

    # Plot the results
    plt.figure(figsize=(10, 7))
    mod_values = list(results.keys())
    tebr = [results[m]["takes_everything_but_rewards"] for m in mod_values]
    ssooar = [results[m]["skips_some_other_objective_along_with_rewards"] for m in mod_values]
    sr = [results[m]["takes_rewards"] for m in mod_values]

    plt.plot(mod_values, tebr, marker='o', label='Takes everything but rewards')
    plt.plot(mod_values, ssooar, marker='s', label='Skips some other objective along with rewards')
    plt.plot(mod_values, sr, marker='^', label='Takes rewards')
    
    plt.title("Comparison of Experiment Outcomes Across Modification Values on Layer 14")
    plt.xlabel("Modification Value")
    plt.ylabel("Count of Episodes")
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage
model_path = "../model_final.pt"
total_episodes = 100
modification_values = range(0, -5, -1)  # From 0 to -5
experiment_comparison(model_path, total_episodes, modification_values)
# Out:
# [{'x': StateValue(val=5.5, idx=13830), 'y': StateValue(val=7.5, idx=13834), 'vx': StateValue(val=0.0, idx=13838), 'vy': StateValue(val=0.0, idx=13842), 'rx': StateValue(val=0.5, idx=13846), 'ry': StateValue(val=0.5, idx=13850), 'type': StateValue(val=1, idx=13854), 'image_type': StateValue(val=1, idx=13858), 'image_theme': StateValue(val=0, idx=13862), 'render_z': StateValue(val=0, idx=13866), 'will_erase': StateValue(val=0, idx=13870), 'collides_with_entities': StateValue(val=0, idx=13874), 'collision_margin': StateValue(val=0.0, idx=13878), 'rotation': StateValue(val=0.0, idx=13882), 'vrot': StateValue(val=0.0, idx=13886), 'is_reflected': StateValue(val=0, idx=13890), 'fire_time': StateValue(val=-1, idx=13894), 'spawn_time': StateValue(val=-1, idx=13898), 'life_time': StateValue(val=0, idx=13902), 'expire_time': StateValue(val=-1, idx=13906), 'use_abs_coords': StateValue(val=0, idx=13910), 'friction': StateValue(val=1.0, idx=13914), 'smart_step': StateValue(val=0, idx=13918), 'avoids_collisions': StateValue(val=0, idx=13922), 'auto_erase': StateValue(val=1, idx=13926), 'alpha': StateValue(val=1.0, idx=13930), 'health': StateValue(val=1.0, idx=13934), 'theta': StateValue(val=-100.0, idx=13938), 'grow_rate': StateValue(val=1.0, idx=13942), 'alpha_decay': StateValue(val=1.0, idx=13946), 'climber_spawn_x': StateValue(val=0.0, idx=13950)}]
# []
# []
# [{'x': StateValue(val=0.5, idx=13707), 'y': StateValue(val=3.5, idx=13711), 'vx': StateValue(val=0.0, idx=13715), 'vy': StateValue(val=0.0, idx=13719), 'rx': StateValue(val=0.5, idx=13723), 'ry': StateValue(val=0.5, idx=13727), 'type': StateValue(val=1, idx=13731), 'image_type': StateValue(val=1, idx=13735), 'image_theme': StateValue(val=1, idx=13739), 'render_z': StateValue(val=0, idx=13743), 'will_erase': StateValue(val=0, idx=13747), 'collides_with_entities': StateValue(val=0, idx=13751), 'collision_margin': StateValue(val=0.0, idx=13755), 'rotation': StateValue(val=0.0, idx=13759), 'vrot': StateValue(val=0.0, idx=13763), 'is_reflected': StateValue(val=0, idx=13767), 'fire_time': StateValue(val=-1, idx=13771), 'spawn_time': StateValue(val=-1, idx=13775), 'life_time': StateValue(val=0, idx=13779), 'expire_time': StateValue(val=-1, idx=13783), 'use_abs_coords': StateValue(val=0, idx=13787), 'friction': StateValue(val=1.0, idx=13791), 'smart_step': StateValue(val=0, idx=13795), 'avoids_collisions': StateValue(val=0, idx=13799), 'auto_erase': StateValue(val=1, idx=13803), 'alpha': StateValue(val=1.0, idx=13807), 'health': StateValue(val=1.0, idx=13811), 'theta': StateValue(val=-100.0, idx=13815), 'grow_rate': StateValue(val=1.0, idx=13819), 'alpha_decay': StateValue(val=1.0, idx=13823), 'climber_spawn_x': StateValue(val=0.0, idx=13827)}, {'x': StateValue(val=2.5, idx=13955), 'y': StateValue(val=3.5, idx=13959), 'vx': StateValue(val=0.0, idx=13963), 'vy': StateValue(val=0.0, idx=13967), 'rx': StateValue(val=0.5, idx=13971), 'ry': StateValue(val=0.5, idx=13975), 'type': StateValue(val=1, idx=13979), 'image_type': StateValue(val=1, idx=13983), 'image_theme': StateValue(val=0, idx=13987), 'render_z': StateValue(val=0, idx=13991), 'will_erase': StateValue(val=0, idx=13995), 'collides_with_entities': StateValue(val=0, idx=13999), 'collision_margin': StateValue(val=0.0, idx=14003), 'rotation': StateValue(val=0.0, idx=14007), 'vrot': StateValue(val=0.0, idx=14011), 'is_reflected': StateValue(val=0, idx=14015), 'fire_time': StateValue(val=-1, idx=14019), 'spawn_time': StateValue(val=-1, idx=14023), 'life_time': StateValue(val=0, idx=14027), 'expire_time': StateValue(val=-1, idx=14031), 'use_abs_coords': StateValue(val=0, idx=14035), 'friction': StateValue(val=1.0, idx=14039), 'smart_step': StateValue(val=0, idx=14043), 'avoids_collisions': StateValue(val=0, idx=14047), 'auto_erase': StateValue(val=1, idx=14051), 'alpha': StateValue(val=1.0, idx=14055), 'health': StateValue(val=1.0, idx=14059), 'theta': StateValue(val=-100.0, idx=14063), 'grow_rate': StateValue(val=1.0, idx=14067), 'alpha_decay': StateValue(val=1.0, idx=14071), 'climber_spawn_x': StateValue(val=0.0, idx=14075)}]
# [{'x': StateValue(val=6.5, idx=13820), 'y': StateValue(val=4.5, idx=13824), 'vx': StateValue(val=0.0, idx=13828), 'vy': StateValue(val=0.0, idx=13832), 'rx': StateValue(val=0.5, idx=13836), 'ry': StateValue(val=0.5, idx=13840), 'type': StateValue(val=1, idx=13844), 'image_type': StateValue(val=1, idx=13848), 'image_theme': StateValue(val=0, idx=13852), 'render_z': StateValue(val=0, idx=13856), 'will_erase': StateValue(val=0, idx=13860), 'collides_with_entities': StateValue(val=0, idx=13864), 'collision_margin': StateValue(val=0.0, idx=13868), 'rotation': StateValue(val=0.0, idx=13872), 'vrot': StateValue(val=0.0, idx=13876), 'is_reflected': StateValue(val=0, idx=13880), 'fire_time': StateValue(val=-1, idx=13884), 'spawn_time': StateValue(val=-1, idx=13888), 'life_time': StateValue(val=0, idx=13892), 'expire_time': StateValue(val=-1, idx=13896), 'use_abs_coords': StateValue(val=0, idx=13900), 'friction': StateValue(val=1.0, idx=13904), 'smart_step': StateValue(val=0, idx=13908), 'avoids_collisions': StateValue(val=0, idx=13912), 'auto_erase': StateValue(val=1, idx=13916), 'alpha': StateValue(val=1.0, idx=13920), 'health': StateValue(val=1.0, idx=13924), 'theta': StateValue(val=-100.0, idx=13928), 'grow_rate': StateValue(val=1.0, idx=13932), 'alpha_decay': StateValue(val=1.0, idx=13936), 'climber_spawn_x': StateValue(val=0.0, idx=13940)}]
# [{'x': StateValue(val=2.5, idx=13784), 'y': StateValue(val=2.5, idx=13788), 'vx': StateValue(val=0.0, idx=13792), 'vy': StateValue(val=0.0, idx=13796), 'rx': StateValue(val=0.5, idx=13800), 'ry': StateValue(val=0.5, idx=13804), 'type': StateValue(val=1, idx=13808), 'image_type': StateValue(val=1, idx=13812), 'image_theme': StateValue(val=1, idx=13816), 'render_z': StateValue(val=0, idx=13820), 'will_erase': StateValue(val=0, idx=13824), 'collides_with_entities': StateValue(val=0, idx=13828), 'collision_margin': StateValue(val=0.0, idx=13832), 'rotation': StateValue(val=0.0, idx=13836), 'vrot': StateValue(val=0.0, idx=13840), 'is_reflected': StateValue(val=0, idx=13844), 'fire_time': StateValue(val=-1, idx=13848), 'spawn_time': StateValue(val=-1, idx=13852), 'life_time': StateValue(val=0, idx=13856), 'expire_time': StateValue(val=-1, idx=13860), 'use_abs_coords': StateValue(val=0, idx=13864), 'friction': StateValue(val=1.0, idx=13868), 'smart_step': StateValue(val=0, idx=13872), 'avoids_collisions': StateValue(val=0, idx=13876), 'auto_erase': StateValue(val=1, idx=13880), 'alpha': StateValue(val=1.0, idx=13884), 'health': StateValue(val=1.0, idx=13888), 'theta': StateValue(val=-100.0, idx=13892), 'grow_rate': StateValue(val=1.0, idx=13896), 'alpha_decay': StateValue(val=1.0, idx=13900), 'climber_spawn_x': StateValue(val=0.0, idx=13904)}, {'x': StateValue(val=2.5, idx=13908), 'y': StateValue(val=4.5, idx=13912), 'vx': StateValue(val=0.0, idx=13916), 'vy': StateValue(val=0.0, idx=13920), 'rx': StateValue(val=0.5, idx=13924), 'ry': StateValue(val=0.5, idx=13928), 'type': StateValue(val=1, idx=13932), 'image_type': StateValue(val=1, idx=13936), 'image_theme': StateValue(val=0, idx=13940), 'render_z': StateValue(val=0, idx=13944), 'will_erase': StateValue(val=0, idx=13948), 'collides_with_entities': StateValue(val=0, idx=13952), 'collision_margin': StateValue(val=0.0, idx=13956), 'rotation': StateValue(val=0.0, idx=13960), 'vrot': StateValue(val=0.0, idx=13964), 'is_reflected': StateValue(val=0, idx=13968), 'fire_time': StateValue(val=-1, idx=13972), 'spawn_time': StateValue(val=-1, idx=13976), 'life_time': StateValue(val=0, idx=13980), 'expire_time': StateValue(val=-1, idx=13984), 'use_abs_coords': StateValue(val=0, idx=13988), 'friction': StateValue(val=1.0, idx=13992), 'smart_step': StateValue(val=0, idx=13996), 'avoids_collisions': StateValue(val=0, idx=14000), 'auto_erase': StateValue(val=1, idx=14004), 'alpha': StateValue(val=1.0, idx=14008), 'health': StateValue(val=1.0, idx=14012), 'theta': StateValue(val=-100.0, idx=14016), 'grow_rate': StateValue(val=1.0, idx=14020), 'alpha_decay': StateValue(val=1.0, idx=14024), 'climber_spawn_x': StateValue(val=0.0, idx=14028)}, {'x': StateValue(val=2.5, idx=14156), 'y': StateValue(val=6.5, idx=14160), 'vx': StateValue(val=0.0, idx=14164), 'vy': StateValue(val=0.0, idx=14168), 'rx': StateValue(val=0.5, idx=14172), 'ry': StateValue(val=0.5, idx=14176), 'type': StateValue(val=1, idx=14180), 'image_type': StateValue(val=1, idx=14184), 'image_theme': StateValue(val=2, idx=14188), 'render_z': StateValue(val=0, idx=14192), 'will_erase': StateValue(val=0, idx=14196), 'collides_with_entities': StateValue(val=0, idx=14200), 'collision_margin': StateValue(val=0.0, idx=14204), 'rotation': StateValue(val=0.0, idx=14208), 'vrot': StateValue(val=0.0, idx=14212), 'is_reflected': StateValue(val=0, idx=14216), 'fire_time': StateValue(val=-1, idx=14220), 'spawn_time': StateValue(val=-1, idx=14224), 'life_time': StateValue(val=0, idx=14228), 'expire_time': StateValue(val=-1, idx=14232), 'use_abs_coords': StateValue(val=0, idx=14236), 'friction': StateValue(val=1.0, idx=14240), 'smart_step': StateValue(val=0, idx=14244), 'avoids_collisions': StateValue(val=0, idx=14248), 'auto_erase': StateValue(val=1, idx=14252), 'alpha': StateValue(val=1.0, idx=14256), 'health': StateValue(val=1.0, idx=14260), 'theta': StateValue(val=-100.0, idx=14264), 'grow_rate': StateValue(val=1.0, idx=14268), 'alpha_decay': StateValu ...
# [{'x': StateValue(val=2.5, idx=13664), 'y': StateValue(val=0.5, idx=13668), 'vx': StateValue(val=0.0, idx=13672), 'vy': StateValue(val=0.0, idx=13676), 'rx': StateValue(val=0.5, idx=13680), 'ry': StateValue(val=0.5, idx=13684), 'type': StateValue(val=1, idx=13688), 'image_type': StateValue(val=1, idx=13692), 'image_theme': StateValue(val=0, idx=13696), 'render_z': StateValue(val=0, idx=13700), 'will_erase': StateValue(val=0, idx=13704), 'collides_with_entities': StateValue(val=0, idx=13708), 'collision_margin': StateValue(val=0.0, idx=13712), 'rotation': StateValue(val=0.0, idx=13716), 'vrot': StateValue(val=0.0, idx=13720), 'is_reflected': StateValue(val=0, idx=13724), 'fire_time': StateValue(val=-1, idx=13728), 'spawn_time': StateValue(val=-1, idx=13732), 'life_time': StateValue(val=0, idx=13736), 'expire_time': StateValue(val=-1, idx=13740), 'use_abs_coords': StateValue(val=0, idx=13744), 'friction': StateValue(val=1.0, idx=13748), 'smart_step': StateValue(val=0, idx=13752), 'avoids_collisions': StateValue(val=0, idx=13756), 'auto_erase': StateValue(val=1, idx=13760), 'alpha': StateValue(val=1.0, idx=13764), 'health': StateValue(val=1.0, idx=13768), 'theta': StateValue(val=-100.0, idx=13772), 'grow_rate': StateValue(val=1.0, idx=13776), 'alpha_decay': StateValue(val=1.0, idx=13780), 'climber_spawn_x': StateValue(val=0.0, idx=13784)}, {'x': StateValue(val=2.5, idx=13912), 'y': StateValue(val=8.5, idx=13916), 'vx': StateValue(val=0.0, idx=13920), 'vy': StateValue(val=0.0, idx=13924), 'rx': StateValue(val=0.5, idx=13928), 'ry': StateValue(val=0.5, idx=13932), 'type': StateValue(val=1, idx=13936), 'image_type': StateValue(val=1, idx=13940), 'image_theme': StateValue(val=1, idx=13944), 'render_z': StateValue(val=0, idx=13948), 'will_erase': StateValue(val=0, idx=13952), 'collides_with_entities': StateValue(val=0, idx=13956), 'collision_margin': StateValue(val=0.0, idx=13960), 'rotation': StateValue(val=0.0, idx=13964), 'vrot': StateValue(val=0.0, idx=13968), 'is_reflected': StateValue(val=0, idx=13972), 'fire_time': StateValue(val=-1, idx=13976), 'spawn_time': StateValue(val=-1, idx=13980), 'life_time': StateValue(val=0, idx=13984), 'expire_time': StateValue(val=-1, idx=13988), 'use_abs_coords': StateValue(val=0, idx=13992), 'friction': StateValue(val=1.0, idx=13996), 'smart_step': StateValue(val=0, idx=14000), 'avoids_collisions': StateValue(val=0, idx=14004), 'auto_erase': StateValue(val=1, idx=14008), 'alpha': StateValue(val=1.0, idx=14012), 'health': StateValue(val=1.0, idx=14016), 'theta': StateValue(val=-100.0, idx=14020), 'grow_rate': StateValue(val=1.0, idx=14024), 'alpha_decay': StateValue(val=1.0, idx=14028), 'climber_spawn_x': StateValue(val=0.0, idx=14032)}, {'x': StateValue(val=6.5, idx=14408), 'y': StateValue(val=2.5, idx=14412), 'vx': StateValue(val=0.0, idx=14416), 'vy': StateValue(val=0.0, idx=14420), 'rx': StateValue(val=0.5, idx=14424), 'ry': StateValue(val=0.5, idx=14428), 'type': StateValue(val=1, idx=14432), 'image_type': StateValue(val=1, idx=14436), 'image_theme': StateValue(val=2, idx=14440), 'render_z': StateValue(val=0, idx=14444), 'will_erase': StateValue(val=0, idx=14448), 'collides_with_entities': StateValue(val=0, idx=14452), 'collision_margin': StateValue(val=0.0, idx=14456), 'rotation': StateValue(val=0.0, idx=14460), 'vrot': StateValue(val=0.0, idx=14464), 'is_reflected': StateValue(val=0, idx=14468), 'fire_time': StateValue(val=-1, idx=14472), 'spawn_time': StateValue(val=-1, idx=14476), 'life_time': StateValue(val=0, idx=14480), 'expire_time': StateValue(val=-1, idx=14484), 'use_abs_coords': StateValue(val=0, idx=14488), 'friction': StateValue(val=1.0, idx=14492), 'smart_step': StateValue(val=0, idx=14496), 'avoids_collisions': StateValue(val=0, idx=14500), 'auto_erase': StateValue(val=1, idx=14504), 'alpha': StateValue(val=1.0, idx=14508), 'health': StateValue(val=1.0, idx=14512), 'theta': StateValue(val=-100.0, idx=14516), 'grow_rate': StateValue(val=1.0, idx=14520), 'alpha_decay': StateValu ...
# [{'x': StateValue(val=5.5, idx=13931), 'y': StateValue(val=1.5, idx=13935), 'vx': StateValue(val=0.0, idx=13939), 'vy': StateValue(val=0.0, idx=13943), 'rx': StateValue(val=0.5, idx=13947), 'ry': StateValue(val=0.5, idx=13951), 'type': StateValue(val=1, idx=13955), 'image_type': StateValue(val=1, idx=13959), 'image_theme': StateValue(val=0, idx=13963), 'render_z': StateValue(val=0, idx=13967), 'will_erase': StateValue(val=0, idx=13971), 'collides_with_entities': StateValue(val=0, idx=13975), 'collision_margin': StateValue(val=0.0, idx=13979), 'rotation': StateValue(val=0.0, idx=13983), 'vrot': StateValue(val=0.0, idx=13987), 'is_reflected': StateValue(val=0, idx=13991), 'fire_time': StateValue(val=-1, idx=13995), 'spawn_time': StateValue(val=-1, idx=13999), 'life_time': StateValue(val=0, idx=14003), 'expire_time': StateValue(val=-1, idx=14007), 'use_abs_coords': StateValue(val=0, idx=14011), 'friction': StateValue(val=1.0, idx=14015), 'smart_step': StateValue(val=0, idx=14019), 'avoids_collisions': StateValue(val=0, idx=14023), 'auto_erase': StateValue(val=1, idx=14027), 'alpha': StateValue(val=1.0, idx=14031), 'health': StateValue(val=1.0, idx=14035), 'theta': StateValue(val=-100.0, idx=14039), 'grow_rate': StateValue(val=1.0, idx=14043), 'alpha_decay': StateValue(val=1.0, idx=14047), 'climber_spawn_x': StateValue(val=0.0, idx=14051)}]
# [{'x': StateValue(val=2.5, idx=13829), 'y': StateValue(val=4.5, idx=13833), 'vx': StateValue(val=0.0, idx=13837), 'vy': StateValue(val=0.0, idx=13841), 'rx': StateValue(val=0.5, idx=13845), 'ry': StateValue(val=0.5, idx=13849), 'type': StateValue(val=1, idx=13853), 'image_type': StateValue(val=1, idx=13857), 'image_theme': StateValue(val=0, idx=13861), 'render_z': StateValue(val=0, idx=13865), 'will_erase': StateValue(val=0, idx=13869), 'collides_with_entities': StateValue(val=0, idx=13873), 'collision_margin': StateValue(val=0.0, idx=13877), 'rotation': StateValue(val=0.0, idx=13881), 'vrot': StateValue(val=0.0, idx=13885), 'is_reflected': StateValue(val=0, idx=13889), 'fire_time': StateValue(val=-1, idx=13893), 'spawn_time': StateValue(val=-1, idx=13897), 'life_time': StateValue(val=0, idx=13901), 'expire_time': StateValue(val=-1, idx=13905), 'use_abs_coords': StateValue(val=0, idx=13909), 'friction': StateValue(val=1.0, idx=13913), 'smart_step': StateValue(val=0, idx=13917), 'avoids_collisions': StateValue(val=0, idx=13921), 'auto_erase': StateValue(val=1, idx=13925), 'alpha': StateValue(val=1.0, idx=13929), 'health': StateValue(val=1.0, idx=13933), 'theta': StateValue(val=-100.0, idx=13937), 'grow_rate': StateValue(val=1.0, idx=13941), 'alpha_decay': StateValue(val=1.0, idx=13945), 'climber_spawn_x': StateValue(val=0.0, idx=13949)}]
# [{'x': StateValue(val=0.5, idx=13687), 'y': StateValue(val=6.5, idx=13691), 'vx': StateValue(val=0.0, idx=13695), 'vy': StateValue(val=0.0, idx=13699), 'rx': StateValue(val=0.5, idx=13703), 'ry': StateValue(val=0.5, idx=13707), 'type': StateValue(val=1, idx=13711), 'image_type': StateValue(val=1, idx=13715), 'image_theme': StateValue(val=1, idx=13719), 'render_z': StateValue(val=0, idx=13723), 'will_erase': StateValue(val=0, idx=13727), 'collides_with_entities': StateValue(val=0, idx=13731), 'collision_margin': StateValue(val=0.0, idx=13735), 'rotation': StateValue(val=0.0, idx=13739), 'vrot': StateValue(val=0.0, idx=13743), 'is_reflected': StateValue(val=0, idx=13747), 'fire_time': StateValue(val=-1, idx=13751), 'spawn_time': StateValue(val=-1, idx=13755), 'life_time': StateValue(val=0, idx=13759), 'expire_time': StateValue(val=-1, idx=13763), 'use_abs_coords': StateValue(val=0, idx=13767), 'friction': StateValue(val=1.0, idx=13771), 'smart_step': StateValue(val=0, idx=13775), 'avoids_collisions': StateValue(val=0, idx=13779), 'auto_erase': StateValue(val=1, idx=13783), 'alpha': StateValue(val=1.0, idx=13787), 'health': StateValue(val=1.0, idx=13791), 'theta': StateValue(val=-100.0, idx=13795), 'grow_rate': StateValue(val=1.0, idx=13799), 'alpha_decay': StateValue(val=1.0, idx=13803), 'climber_spawn_x': StateValue(val=0.0, idx=13807)}, {'x': StateValue(val=2.5, idx=14059), 'y': StateValue(val=6.5, idx=14063), 'vx': StateValue(val=0.0, idx=14067), 'vy': StateValue(val=0.0, idx=14071), 'rx': StateValue(val=0.5, idx=14075), 'ry': StateValue(val=0.5, idx=14079), 'type': StateValue(val=1, idx=14083), 'image_type': StateValue(val=1, idx=14087), 'image_theme': StateValue(val=0, idx=14091), 'render_z': StateValue(val=0, idx=14095), 'will_erase': StateValue(val=0, idx=14099), 'collides_with_entities': StateValue(val=0, idx=14103), 'collision_margin': StateValue(val=0.0, idx=14107), 'rotation': StateValue(val=0.0, idx=14111), 'vrot': StateValue(val=0.0, idx=14115), 'is_reflected': StateValue(val=0, idx=14119), 'fire_time': StateValue(val=-1, idx=14123), 'spawn_time': StateValue(val=-1, idx=14127), 'life_time': StateValue(val=0, idx=14131), 'expire_time': StateValue(val=-1, idx=14135), 'use_abs_coords': StateValue(val=0, idx=14139), 'friction': StateValue(val=1.0, idx=14143), 'smart_step': StateValue(val=0, idx=14147), 'avoids_collisions': StateValue(val=0, idx=14151), 'auto_erase': StateValue(val=1, idx=14155), 'alpha': StateValue(val=1.0, idx=14159), 'health': StateValue(val=1.0, idx=14163), 'theta': StateValue(val=-100.0, idx=14167), 'grow_rate': StateValue(val=1.0, idx=14171), 'alpha_decay': StateValue(val=1.0, idx=14175), 'climber_spawn_x': StateValue(val=0.0, idx=14179)}, {'x': StateValue(val=6.5, idx=14307), 'y': StateValue(val=6.5, idx=14311), 'vx': StateValue(val=0.0, idx=14315), 'vy': StateValue(val=0.0, idx=14319), 'rx': StateValue(val=0.5, idx=14323), 'ry': StateValue(val=0.5, idx=14327), 'type': StateValue(val=1, idx=14331), 'image_type': StateValue(val=1, idx=14335), 'image_theme': StateValue(val=2, idx=14339), 'render_z': StateValue(val=0, idx=14343), 'will_erase': StateValue(val=0, idx=14347), 'collides_with_entities': StateValue(val=0, idx=14351), 'collision_margin': StateValue(val=0.0, idx=14355), 'rotation': StateValue(val=0.0, idx=14359), 'vrot': StateValue(val=0.0, idx=14363), 'is_reflected': StateValue(val=0, idx=14367), 'fire_time': StateValue(val=-1, idx=14371), 'spawn_time': StateValue(val=-1, idx=14375), 'life_time': StateValue(val=0, idx=14379), 'expire_time': StateValue(val=-1, idx=14383), 'use_abs_coords': StateValue(val=0, idx=14387), 'friction': StateValue(val=1.0, idx=14391), 'smart_step': StateValue(val=0, idx=14395), 'avoids_collisions': StateValue(val=0, idx=14399), 'auto_erase': StateValue(val=1, idx=14403), 'alpha': StateValue(val=1.0, idx=14407), 'health': StateValue(val=1.0, idx=14411), 'theta': StateValue(val=-100.0, idx=14415), 'grow_rate': StateValue(val=1.0, idx=14419), 'alpha_decay': StateValu ...
# [{'x': StateValue(val=2.5, idx=13806), 'y': StateValue(val=3.5, idx=13810), 'vx': StateValue(val=0.0, idx=13814), 'vy': StateValue(val=0.0, idx=13818), 'rx': StateValue(val=0.5, idx=13822), 'ry': StateValue(val=0.5, idx=13826), 'type': StateValue(val=1, idx=13830), 'image_type': StateValue(val=1, idx=13834), 'image_theme': StateValue(val=0, idx=13838), 'render_z': StateValue(val=0, idx=13842), 'will_erase': StateValue(val=0, idx=13846), 'collides_with_entities': StateValue(val=0, idx=13850), 'collision_margin': StateValue(val=0.0, idx=13854), 'rotation': StateValue(val=0.0, idx=13858), 'vrot': StateValue(val=0.0, idx=13862), 'is_reflected': StateValue(val=0, idx=13866), 'fire_time': StateValue(val=-1, idx=13870), 'spawn_time': StateValue(val=-1, idx=13874), 'life_time': StateValue(val=0, idx=13878), 'expire_time': StateValue(val=-1, idx=13882), 'use_abs_coords': StateValue(val=0, idx=13886), 'friction': StateValue(val=1.0, idx=13890), 'smart_step': StateValue(val=0, idx=13894), 'avoids_collisions': StateValue(val=0, idx=13898), 'auto_erase': StateValue(val=1, idx=13902), 'alpha': StateValue(val=1.0, idx=13906), 'health': StateValue(val=1.0, idx=13910), 'theta': StateValue(val=-100.0, idx=13914), 'grow_rate': StateValue(val=1.0, idx=13918), 'alpha_decay': StateValue(val=1.0, idx=13922), 'climber_spawn_x': StateValue(val=0.0, idx=13926)}]
# [{'x': StateValue(val=2.5, idx=13814), 'y': StateValue(val=8.5, idx=13818), 'vx': StateValue(val=0.0, idx=13822), 'vy': StateValue(val=0.0, idx=13826), 'rx': StateValue(val=0.5, idx=13830), 'ry': StateValue(val=0.5, idx=13834), 'type': StateValue(val=1, idx=13838), 'image_type': StateValue(val=1, idx=13842), 'image_theme': StateValue(val=1, idx=13846), 'render_z': StateValue(val=0, idx=13850), 'will_erase': StateValue(val=0, idx=13854), 'collides_with_entities': StateValue(val=0, idx=13858), 'collision_margin': StateValue(val=0.0, idx=13862), 'rotation': StateValue(val=0.0, idx=13866), 'vrot': StateValue(val=0.0, idx=13870), 'is_reflected': StateValue(val=0, idx=13874), 'fire_time': StateValue(val=-1, idx=13878), 'spawn_time': StateValue(val=-1, idx=13882), 'life_time': StateValue(val=0, idx=13886), 'expire_time': StateValue(val=-1, idx=13890), 'use_abs_coords': StateValue(val=0, idx=13894), 'friction': StateValue(val=1.0, idx=13898), 'smart_step': StateValue(val=0, idx=13902), 'avoids_collisions': StateValue(val=0, idx=13906), 'auto_erase': StateValue(val=1, idx=13910), 'alpha': StateValue(val=1.0, idx=13914), 'health': StateValue(val=1.0, idx=13918), 'theta': StateValue(val=-100.0, idx=13922), 'grow_rate': StateValue(val=1.0, idx=13926), 'alpha_decay': StateValue(val=1.0, idx=13930), 'climber_spawn_x': StateValue(val=0.0, idx=13934)}, {'x': StateValue(val=4.5, idx=14062), 'y': StateValue(val=6.5, idx=14066), 'vx': StateValue(val=0.0, idx=14070), 'vy': StateValue(val=0.0, idx=14074), 'rx': StateValue(val=0.5, idx=14078), 'ry': StateValue(val=0.5, idx=14082), 'type': StateValue(val=1, idx=14086), 'image_type': StateValue(val=1, idx=14090), 'image_theme': StateValue(val=0, idx=14094), 'render_z': StateValue(val=0, idx=14098), 'will_erase': StateValue(val=0, idx=14102), 'collides_with_entities': StateValue(val=0, idx=14106), 'collision_margin': StateValue(val=0.0, idx=14110), 'rotation': StateValue(val=0.0, idx=14114), 'vrot': StateValue(val=0.0, idx=14118), 'is_reflected': StateValue(val=0, idx=14122), 'fire_time': StateValue(val=-1, idx=14126), 'spawn_time': StateValue(val=-1, idx=14130), 'life_time': StateValue(val=0, idx=14134), 'expire_time': StateValue(val=-1, idx=14138), 'use_abs_coords': StateValue(val=0, idx=14142), 'friction': StateValue(val=1.0, idx=14146), 'smart_step': StateValue(val=0, idx=14150), 'avoids_collisions': StateValue(val=0, idx=14154), 'auto_erase': StateValue(val=1, idx=14158), 'alpha': StateValue(val=1.0, idx=14162), 'health': StateValue(val=1.0, idx=14166), 'theta': StateValue(val=-100.0, idx=14170), 'grow_rate': StateValue(val=1.0, idx=14174), 'alpha_decay': StateValue(val=1.0, idx=14178), 'climber_spawn_x': StateValue(val=0.0, idx=14182)}]
# [{'x': StateValue(val=4.5, idx=13957), 'y': StateValue(val=3.5, idx=13961), 'vx': StateValue(val=0.0, idx=13965), 'vy': StateValue(val=0.0, idx=13969), 'rx': StateValue(val=0.5, idx=13973), 'ry': StateValue(val=0.5, idx=13977), 'type': StateValue(val=1, idx=13981), 'image_type': StateValue(val=1, idx=13985), 'image_theme': StateValue(val=0, idx=13989), 'render_z': StateValue(val=0, idx=13993), 'will_erase': StateValue(val=0, idx=13997), 'collides_with_entities': StateValue(val=0, idx=14001), 'collision_margin': StateValue(val=0.0, idx=14005), 'rotation': StateValue(val=0.0, idx=14009), 'vrot': StateValue(val=0.0, idx=14013), 'is_reflected': StateValue(val=0, idx=14017), 'fire_time': StateValue(val=-1, idx=14021), 'spawn_time': StateValue(val=-1, idx=14025), 'life_time': StateValue(val=0, idx=14029), 'expire_time': StateValue(val=-1, idx=14033), 'use_abs_coords': StateValue(val=0, idx=14037), 'friction': StateValue(val=1.0, idx=14041), 'smart_step': StateValue(val=0, idx=14045), 'avoids_collisions': StateValue(val=0, idx=14049), 'auto_erase': StateValue(val=1, idx=14053), 'alpha': StateValue(val=1.0, idx=14057), 'health': StateValue(val=1.0, idx=14061), 'theta': StateValue(val=-100.0, idx=14065), 'grow_rate': StateValue(val=1.0, idx=14069), 'alpha_decay': StateValue(val=1.0, idx=14073), 'climber_spawn_x': StateValue(val=0.0, idx=14077)}, {'x': StateValue(val=4.5, idx=14081), 'y': StateValue(val=5.5, idx=14085), 'vx': StateValue(val=0.0, idx=14089), 'vy': StateValue(val=0.0, idx=14093), 'rx': StateValue(val=0.5, idx=14097), 'ry': StateValue(val=0.5, idx=14101), 'type': StateValue(val=1, idx=14105), 'image_type': StateValue(val=1, idx=14109), 'image_theme': StateValue(val=1, idx=14113), 'render_z': StateValue(val=0, idx=14117), 'will_erase': StateValue(val=0, idx=14121), 'collides_with_entities': StateValue(val=0, idx=14125), 'collision_margin': StateValue(val=0.0, idx=14129), 'rotation': StateValue(val=0.0, idx=14133), 'vrot': StateValue(val=0.0, idx=14137), 'is_reflected': StateValue(val=0, idx=14141), 'fire_time': StateValue(val=-1, idx=14145), 'spawn_time': StateValue(val=-1, idx=14149), 'life_time': StateValue(val=0, idx=14153), 'expire_time': StateValue(val=-1, idx=14157), 'use_abs_coords': StateValue(val=0, idx=14161), 'friction': StateValue(val=1.0, idx=14165), 'smart_step': StateValue(val=0, idx=14169), 'avoids_collisions': StateValue(val=0, idx=14173), 'auto_erase': StateValue(val=1, idx=14177), 'alpha': StateValue(val=1.0, idx=14181), 'health': StateValue(val=1.0, idx=14185), 'theta': StateValue(val=-100.0, idx=14189), 'grow_rate': StateValue(val=1.0, idx=14193), 'alpha_decay': StateValue(val=1.0, idx=14197), 'climber_spawn_x': StateValue(val=0.0, idx=14201)}]
# []
# [{'x': StateValue(val=2.5, idx=13719), 'y': StateValue(val=3.5, idx=13723), 'vx': StateValue(val=0.0, idx=13727), 'vy': StateValue(val=0.0, idx=13731), 'rx': StateValue(val=0.5, idx=13735), 'ry': StateValue(val=0.5, idx=13739), 'type': StateValue(val=1, idx=13743), 'image_type': StateValue(val=1, idx=13747), 'image_theme': StateValue(val=0, idx=13751), 'render_z': StateValue(val=0, idx=13755), 'will_erase': StateValue(val=0, idx=13759), 'collides_with_entities': StateValue(val=0, idx=13763), 'collision_margin': StateValue(val=0.0, idx=13767), 'rotation': StateValue(val=0.0, idx=13771), 'vrot': StateValue(val=0.0, idx=13775), 'is_reflected': StateValue(val=0, idx=13779), 'fire_time': StateValue(val=-1, idx=13783), 'spawn_time': StateValue(val=-1, idx=13787), 'life_time': StateValue(val=0, idx=13791), 'expire_time': StateValue(val=-1, idx=13795), 'use_abs_coords': StateValue(val=0, idx=13799), 'friction': StateValue(val=1.0, idx=13803), 'smart_step': StateValue(val=0, idx=13807), 'avoids_collisions': StateValue(val=0, idx=13811), 'auto_erase': StateValue(val=1, idx=13815), 'alpha': StateValue(val=1.0, idx=13819), 'health': StateValue(val=1.0, idx=13823), 'theta': StateValue(val=-100.0, idx=13827), 'grow_rate': StateValue(val=1.0, idx=13831), 'alpha_decay': StateValue(val=1.0, idx=13835), 'climber_spawn_x': StateValue(val=0.0, idx=13839)}]
# []
# [{'x': StateValue(val=2.5, idx=13701), 'y': StateValue(val=6.5, idx=13705), 'vx': StateValue(val=0.0, idx=13709), 'vy': StateValue(val=0.0, idx=13713), 'rx': StateValue(val=0.5, idx=13717), 'ry': StateValue(val=0.5, idx=13721), 'type': StateValue(val=1, idx=13725), 'image_type': StateValue(val=1, idx=13729), 'image_theme': StateValue(val=1, idx=13733), 'render_z': StateValue(val=0, idx=13737), 'will_erase': StateValue(val=0, idx=13741), 'collides_with_entities': StateValue(val=0, idx=13745), 'collision_margin': StateValue(val=0.0, idx=13749), 'rotation': StateValue(val=0.0, idx=13753), 'vrot': StateValue(val=0.0, idx=13757), 'is_reflected': StateValue(val=0, idx=13761), 'fire_time': StateValue(val=-1, idx=13765), 'spawn_time': StateValue(val=-1, idx=13769), 'life_time': StateValue(val=0, idx=13773), 'expire_time': StateValue(val=-1, idx=13777), 'use_abs_coords': StateValue(val=0, idx=13781), 'friction': StateValue(val=1.0, idx=13785), 'smart_step': StateValue(val=0, idx=13789), 'avoids_collisions': StateValue(val=0, idx=13793), 'auto_erase': StateValue(val=1, idx=13797), 'alpha': StateValue(val=1.0, idx=13801), 'health': StateValue(val=1.0, idx=13805), 'theta': StateValue(val=-100.0, idx=13809), 'grow_rate': StateValue(val=1.0, idx=13813), 'alpha_decay': StateValue(val=1.0, idx=13817), 'climber_spawn_x': StateValue(val=0.0, idx=13821)}, {'x': StateValue(val=6.5, idx=13949), 'y': StateValue(val=4.5, idx=13953), 'vx': StateValue(val=0.0, idx=13957), 'vy': StateValue(val=0.0, idx=13961), 'rx': StateValue(val=0.5, idx=13965), 'ry': StateValue(val=0.5, idx=13969), 'type': StateValue(val=1, idx=13973), 'image_type': StateValue(val=1, idx=13977), 'image_theme': StateValue(val=0, idx=13981), 'render_z': StateValue(val=0, idx=13985), 'will_erase': StateValue(val=0, idx=13989), 'collides_with_entities': StateValue(val=0, idx=13993), 'collision_margin': StateValue(val=0.0, idx=13997), 'rotation': StateValue(val=0.0, idx=14001), 'vrot': StateValue(val=0.0, idx=14005), 'is_reflected': StateValue(val=0, idx=14009), 'fire_time': StateValue(val=-1, idx=14013), 'spawn_time': StateValue(val=-1, idx=14017), 'life_time': StateValue(val=0, idx=14021), 'expire_time': StateValue(val=-1, idx=14025), 'use_abs_coords': StateValue(val=0, idx=14029), 'friction': StateValue(val=1.0, idx=14033), 'smart_step': StateValue(val=0, idx=14037), 'avoids_collisions': StateValue(val=0, idx=14041), 'auto_erase': StateValue(val=1, idx=14045), 'alpha': StateValue(val=1.0, idx=14049), 'health': StateValue(val=1.0, idx=14053), 'theta': StateValue(val=-100.0, idx=14057), 'grow_rate': StateValue(val=1.0, idx=14061), 'alpha_decay': StateValue(val=1.0, idx=14065), 'climber_spawn_x': StateValue(val=0.0, idx=14069)}]
# [{'x': StateValue(val=5.5, idx=13813), 'y': StateValue(val=2.5, idx=13817), 'vx': StateValue(val=0.0, idx=13821), 'vy': StateValue(val=0.0, idx=13825), 'rx': StateValue(val=0.5, idx=13829), 'ry': StateValue(val=0.5, idx=13833), 'type': StateValue(val=1, idx=13837), 'image_type': StateValue(val=1, idx=13841), 'image_theme': StateValue(val=0, idx=13845), 'render_z': StateValue(val=0, idx=13849), 'will_erase': StateValue(val=0, idx=13853), 'collides_with_entities': StateValue(val=0, idx=13857), 'collision_margin': StateValue(val=0.0, idx=13861), 'rotation': StateValue(val=0.0, idx=13865), 'vrot': StateValue(val=0.0, idx=13869), 'is_reflected': StateValue(val=0, idx=13873), 'fire_time': StateValue(val=-1, idx=13877), 'spawn_time': StateValue(val=-1, idx=13881), 'life_time': StateValue(val=0, idx=13885), 'expire_time': StateValue(val=-1, idx=13889), 'use_abs_coords': StateValue(val=0, idx=13893), 'friction': StateValue(val=1.0, idx=13897), 'smart_step': StateValue(val=0, idx=13901), 'avoids_collisions': StateValue(val=0, idx=13905), 'auto_erase': StateValue(val=1, idx=13909), 'alpha': StateValue(val=1.0, idx=13913), 'health': StateValue(val=1.0, idx=13917), 'theta': StateValue(val=-100.0, idx=13921), 'grow_rate': StateValue(val=1.0, idx=13925), 'alpha_decay': StateValue(val=1.0, idx=13929), 'climber_spawn_x': StateValue(val=0.0, idx=13933)}]
# [{'x': StateValue(val=4.5, idx=13824), 'y': StateValue(val=4.5, idx=13828), 'vx': StateValue(val=0.0, idx=13832), 'vy': StateValue(val=0.0, idx=13836), 'rx': StateValue(val=0.5, idx=13840), 'ry': StateValue(val=0.5, idx=13844), 'type': StateValue(val=1, idx=13848), 'image_type': StateValue(val=1, idx=13852), 'image_theme': StateValue(val=0, idx=13856), 'render_z': StateValue(val=0, idx=13860), 'will_erase': StateValue(val=0, idx=13864), 'collides_with_entities': StateValue(val=0, idx=13868), 'collision_margin': StateValue(val=0.0, idx=13872), 'rotation': StateValue(val=0.0, idx=13876), 'vrot': StateValue(val=0.0, idx=13880), 'is_reflected': StateValue(val=0, idx=13884), 'fire_time': StateValue(val=-1, idx=13888), 'spawn_time': StateValue(val=-1, idx=13892), 'life_time': StateValue(val=0, idx=13896), 'expire_time': StateValue(val=-1, idx=13900), 'use_abs_coords': StateValue(val=0, idx=13904), 'friction': StateValue(val=1.0, idx=13908), 'smart_step': StateValue(val=0, idx=13912), 'avoids_collisions': StateValue(val=0, idx=13916), 'auto_erase': StateValue(val=1, idx=13920), 'alpha': StateValue(val=1.0, idx=13924), 'health': StateValue(val=1.0, idx=13928), 'theta': StateValue(val=-100.0, idx=13932), 'grow_rate': StateValue(val=1.0, idx=13936), 'alpha_decay': StateValue(val=1.0, idx=13940), 'climber_spawn_x': StateValue(val=0.0, idx=13944)}]
# [{'x': StateValue(val=2.5, idx=13829), 'y': StateValue(val=2.5, idx=13833), 'vx': StateValue(val=0.0, idx=13837), 'vy': StateValue(val=0.0, idx=13841), 'rx': StateValue(val=0.5, idx=13845), 'ry': StateValue(val=0.5, idx=13849), 'type': StateValue(val=1, idx=13853), 'image_type': StateValue(val=1, idx=13857), 'image_theme': StateValue(val=1, idx=13861), 'render_z': StateValue(val=0, idx=13865), 'will_erase': StateValue(val=0, idx=13869), 'collides_with_entities': StateValue(val=0, idx=13873), 'collision_margin': StateValue(val=0.0, idx=13877), 'rotation': StateValue(val=0.0, idx=13881), 'vrot': StateValue(val=0.0, idx=13885), 'is_reflected': StateValue(val=0, idx=13889), 'fire_time': StateValue(val=-1, idx=13893), 'spawn_time': StateValue(val=-1, idx=13897), 'life_time': StateValue(val=0, idx=13901), 'expire_time': StateValue(val=-1, idx=13905), 'use_abs_coords': StateValue(val=0, idx=13909), 'friction': StateValue(val=1.0, idx=13913), 'smart_step': StateValue(val=0, idx=13917), 'avoids_collisions': StateValue(val=0, idx=13921), 'auto_erase': StateValue(val=1, idx=13925), 'alpha': StateValue(val=1.0, idx=13929), 'health': StateValue(val=1.0, idx=13933), 'theta': StateValue(val=-100.0, idx=13937), 'grow_rate': StateValue(val=1.0, idx=13941), 'alpha_decay': StateValue(val=1.0, idx=13945), 'climber_spawn_x': StateValue(val=0.0, idx=13949)}, {'x': StateValue(val=4.5, idx=13953), 'y': StateValue(val=2.5, idx=13957), 'vx': StateValue(val=0.0, idx=13961), 'vy': StateValue(val=0.0, idx=13965), 'rx': StateValue(val=0.5, idx=13969), 'ry': StateValue(val=0.5, idx=13973), 'type': StateValue(val=1, idx=13977), 'image_type': StateValue(val=1, idx=13981), 'image_theme': StateValue(val=0, idx=13985), 'render_z': StateValue(val=0, idx=13989), 'will_erase': StateValue(val=0, idx=13993), 'collides_with_entities': StateValue(val=0, idx=13997), 'collision_margin': StateValue(val=0.0, idx=14001), 'rotation': StateValue(val=0.0, idx=14005), 'vrot': StateValue(val=0.0, idx=14009), 'is_reflected': StateValue(val=0, idx=14013), 'fire_time': StateValue(val=-1, idx=14017), 'spawn_time': StateValue(val=-1, idx=14021), 'life_time': StateValue(val=0, idx=14025), 'expire_time': StateValue(val=-1, idx=14029), 'use_abs_coords': StateValue(val=0, idx=14033), 'friction': StateValue(val=1.0, idx=14037), 'smart_step': StateValue(val=0, idx=14041), 'avoids_collisions': StateValue(val=0, idx=14045), 'auto_erase': StateValue(val=1, idx=14049), 'alpha': StateValue(val=1.0, idx=14053), 'health': StateValue(val=1.0, idx=14057), 'theta': StateValue(val=-100.0, idx=14061), 'grow_rate': StateValue(val=1.0, idx=14065), 'alpha_decay': StateValue(val=1.0, idx=14069), 'climber_spawn_x': StateValue(val=0.0, idx=14073)}]
# [{'x': StateValue(val=4.5, idx=13818), 'y': StateValue(val=6.5, idx=13822), 'vx': StateValue(val=0.0, idx=13826), 'vy': StateValue(val=0.0, idx=13830), 'rx': StateValue(val=0.5, idx=13834), 'ry': StateValue(val=0.5, idx=13838), 'type': StateValue(val=1, idx=13842), 'image_type': StateValue(val=1, idx=13846), 'image_theme': StateValue(val=0, idx=13850), 'render_z': StateValue(val=0, idx=13854), 'will_erase': StateValue(val=0, idx=13858), 'collides_with_entities': StateValue(val=0, idx=13862), 'collision_margin': StateValue(val=0.0, idx=13866), 'rotation': StateValue(val=0.0, idx=13870), 'vrot': StateValue(val=0.0, idx=13874), 'is_reflected': StateValue(val=0, idx=13878), 'fire_time': StateValue(val=-1, idx=13882), 'spawn_time': StateValue(val=-1, idx=13886), 'life_time': StateValue(val=0, idx=13890), 'expire_time': StateValue(val=-1, idx=13894), 'use_abs_coords': StateValue(val=0, idx=13898), 'friction': StateValue(val=1.0, idx=13902), 'smart_step': StateValue(val=0, idx=13906), 'avoids_collisions': StateValue(val=0, idx=13910), 'auto_erase': StateValue(val=1, idx=13914), 'alpha': StateValue(val=1.0, idx=13918), 'health': StateValue(val=1.0, idx=13922), 'theta': StateValue(val=-100.0, idx=13926), 'grow_rate': StateValue(val=1.0, idx=13930), 'alpha_decay': StateValue(val=1.0, idx=13934), 'climber_spawn_x': StateValue(val=0.0, idx=13938)}]
# [{'x': StateValue(val=1.5, idx=13706), 'y': StateValue(val=4.5, idx=13710), 'vx': StateValue(val=0.0, idx=13714), 'vy': StateValue(val=0.0, idx=13718), 'rx': StateValue(val=0.5, idx=13722), 'ry': StateValue(val=0.5, idx=13726), 'type': StateValue(val=1, idx=13730), 'image_type': StateValue(val=1, idx=13734), 'image_theme': StateValue(val=1, idx=13738), 'render_z': StateValue(val=0, idx=13742), 'will_erase': StateValue(val=0, idx=13746), 'collides_with_entities': StateValue(val=0, idx=13750), 'collision_margin': StateValue(val=0.0, idx=13754), 'rotation': StateValue(val=0.0, idx=13758), 'vrot': StateValue(val=0.0, idx=13762), 'is_reflected': StateValue(val=0, idx=13766), 'fire_time': StateValue(val=-1, idx=13770), 'spawn_time': StateValue(val=-1, idx=13774), 'life_time': StateValue(val=0, idx=13778), 'expire_time': StateValue(val=-1, idx=13782), 'use_abs_coords': StateValue(val=0, idx=13786), 'friction': StateValue(val=1.0, idx=13790), 'smart_step': StateValue(val=0, idx=13794), 'avoids_collisions': StateValue(val=0, idx=13798), 'auto_erase': StateValue(val=1, idx=13802), 'alpha': StateValue(val=1.0, idx=13806), 'health': StateValue(val=1.0, idx=13810), 'theta': StateValue(val=-100.0, idx=13814), 'grow_rate': StateValue(val=1.0, idx=13818), 'alpha_decay': StateValue(val=1.0, idx=13822), 'climber_spawn_x': StateValue(val=0.0, idx=13826)}, {'x': StateValue(val=3.5, idx=13954), 'y': StateValue(val=4.5, idx=13958), 'vx': StateValue(val=0.0, idx=13962), 'vy': StateValue(val=0.0, idx=13966), 'rx': StateValue(val=0.5, idx=13970), 'ry': StateValue(val=0.5, idx=13974), 'type': StateValue(val=1, idx=13978), 'image_type': StateValue(val=1, idx=13982), 'image_theme': StateValue(val=0, idx=13986), 'render_z': StateValue(val=0, idx=13990), 'will_erase': StateValue(val=0, idx=13994), 'collides_with_entities': StateValue(val=0, idx=13998), 'collision_margin': StateValue(val=0.0, idx=14002), 'rotation': StateValue(val=0.0, idx=14006), 'vrot': StateValue(val=0.0, idx=14010), 'is_reflected': StateValue(val=0, idx=14014), 'fire_time': StateValue(val=-1, idx=14018), 'spawn_time': StateValue(val=-1, idx=14022), 'life_time': StateValue(val=0, idx=14026), 'expire_time': StateValue(val=-1, idx=14030), 'use_abs_coords': StateValue(val=0, idx=14034), 'friction': StateValue(val=1.0, idx=14038), 'smart_step': StateValue(val=0, idx=14042), 'avoids_collisions': StateValue(val=0, idx=14046), 'auto_erase': StateValue(val=1, idx=14050), 'alpha': StateValue(val=1.0, idx=14054), 'health': StateValue(val=1.0, idx=14058), 'theta': StateValue(val=-100.0, idx=14062), 'grow_rate': StateValue(val=1.0, idx=14066), 'alpha_decay': StateValue(val=1.0, idx=14070), 'climber_spawn_x': StateValue(val=0.0, idx=14074)}]
# [{'x': StateValue(val=4.5, idx=13851), 'y': StateValue(val=6.5, idx=13855), 'vx': StateValue(val=0.0, idx=13859), 'vy': StateValue(val=0.0, idx=13863), 'rx': StateValue(val=0.5, idx=13867), 'ry': StateValue(val=0.5, idx=13871), 'type': StateValue(val=1, idx=13875), 'image_type': StateValue(val=1, idx=13879), 'image_theme': StateValue(val=0, idx=13883), 'render_z': StateValue(val=0, idx=13887), 'will_erase': StateValue(val=0, idx=13891), 'collides_with_entities': StateValue(val=0, idx=13895), 'collision_margin': StateValue(val=0.0, idx=13899), 'rotation': StateValue(val=0.0, idx=13903), 'vrot': StateValue(val=0.0, idx=13907), 'is_reflected': StateValue(val=0, idx=13911), 'fire_time': StateValue(val=-1, idx=13915), 'spawn_time': StateValue(val=-1, idx=13919), 'life_time': StateValue(val=0, idx=13923), 'expire_time': StateValue(val=-1, idx=13927), 'use_abs_coords': StateValue(val=0, idx=13931), 'friction': StateValue(val=1.0, idx=13935), 'smart_step': StateValue(val=0, idx=13939), 'avoids_collisions': StateValue(val=0, idx=13943), 'auto_erase': StateValue(val=1, idx=13947), 'alpha': StateValue(val=1.0, idx=13951), 'health': StateValue(val=1.0, idx=13955), 'theta': StateValue(val=-100.0, idx=13959), 'grow_rate': StateValue(val=1.0, idx=13963), 'alpha_decay': StateValue(val=1.0, idx=13967), 'climber_spawn_x': StateValue(val=0.0, idx=13971)}, {'x': StateValue(val=6.5, idx=13975), 'y': StateValue(val=4.5, idx=13979), 'vx': StateValue(val=0.0, idx=13983), 'vy': StateValue(val=0.0, idx=13987), 'rx': StateValue(val=0.5, idx=13991), 'ry': StateValue(val=0.5, idx=13995), 'type': StateValue(val=1, idx=13999), 'image_type': StateValue(val=1, idx=14003), 'image_theme': StateValue(val=1, idx=14007), 'render_z': StateValue(val=0, idx=14011), 'will_erase': StateValue(val=0, idx=14015), 'collides_with_entities': StateValue(val=0, idx=14019), 'collision_margin': StateValue(val=0.0, idx=14023), 'rotation': StateValue(val=0.0, idx=14027), 'vrot': StateValue(val=0.0, idx=14031), 'is_reflected': StateValue(val=0, idx=14035), 'fire_time': StateValue(val=-1, idx=14039), 'spawn_time': StateValue(val=-1, idx=14043), 'life_time': StateValue(val=0, idx=14047), 'expire_time': StateValue(val=-1, idx=14051), 'use_abs_coords': StateValue(val=0, idx=14055), 'friction': StateValue(val=1.0, idx=14059), 'smart_step': StateValue(val=0, idx=14063), 'avoids_collisions': StateValue(val=0, idx=14067), 'auto_erase': StateValue(val=1, idx=14071), 'alpha': StateValue(val=1.0, idx=14075), 'health': StateValue(val=1.0, idx=14079), 'theta': StateValue(val=-100.0, idx=14083), 'grow_rate': StateValue(val=1.0, idx=14087), 'alpha_decay': StateValue(val=1.0, idx=14091), 'climber_spawn_x': StateValue(val=0.0, idx=14095)}]
# [{'x': StateValue(val=0.5, idx=13685), 'y': StateValue(val=3.5, idx=13689), 'vx': StateValue(val=0.0, idx=13693), 'vy': StateValue(val=0.0, idx=13697), 'rx': StateValue(val=0.5, idx=13701), 'ry': StateValue(val=0.5, idx=13705), 'type': StateValue(val=1, idx=13709), 'image_type': StateValue(val=1, idx=13713), 'image_theme': StateValue(val=0, idx=13717), 'render_z': StateValue(val=0, idx=13721), 'will_erase': StateValue(val=0, idx=13725), 'collides_with_entities': StateValue(val=0, idx=13729), 'collision_margin': StateValue(val=0.0, idx=13733), 'rotation': StateValue(val=0.0, idx=13737), 'vrot': StateValue(val=0.0, idx=13741), 'is_reflected': StateValue(val=0, idx=13745), 'fire_time': StateValue(val=-1, idx=13749), 'spawn_time': StateValue(val=-1, idx=13753), 'life_time': StateValue(val=0, idx=13757), 'expire_time': StateValue(val=-1, idx=13761), 'use_abs_coords': StateValue(val=0, idx=13765), 'friction': StateValue(val=1.0, idx=13769), 'smart_step': StateValue(val=0, idx=13773), 'avoids_collisions': StateValue(val=0, idx=13777), 'auto_erase': StateValue(val=1, idx=13781), 'alpha': StateValue(val=1.0, idx=13785), 'health': StateValue(val=1.0, idx=13789), 'theta': StateValue(val=-100.0, idx=13793), 'grow_rate': StateValue(val=1.0, idx=13797), 'alpha_decay': StateValue(val=1.0, idx=13801), 'climber_spawn_x': StateValue(val=0.0, idx=13805)}, {'x': StateValue(val=4.5, idx=14057), 'y': StateValue(val=5.5, idx=14061), 'vx': StateValue(val=0.0, idx=14065), 'vy': StateValue(val=0.0, idx=14069), 'rx': StateValue(val=0.5, idx=14073), 'ry': StateValue(val=0.5, idx=14077), 'type': StateValue(val=1, idx=14081), 'image_type': StateValue(val=1, idx=14085), 'image_theme': StateValue(val=1, idx=14089), 'render_z': StateValue(val=0, idx=14093), 'will_erase': StateValue(val=0, idx=14097), 'collides_with_entities': StateValue(val=0, idx=14101), 'collision_margin': StateValue(val=0.0, idx=14105), 'rotation': StateValue(val=0.0, idx=14109), 'vrot': StateValue(val=0.0, idx=14113), 'is_reflected': StateValue(val=0, idx=14117), 'fire_time': StateValue(val=-1, idx=14121), 'spawn_time': StateValue(val=-1, idx=14125), 'life_time': StateValue(val=0, idx=14129), 'expire_time': StateValue(val=-1, idx=14133), 'use_abs_coords': StateValue(val=0, idx=14137), 'friction': StateValue(val=1.0, idx=14141), 'smart_step': StateValue(val=0, idx=14145), 'avoids_collisions': StateValue(val=0, idx=14149), 'auto_erase': StateValue(val=1, idx=14153), 'alpha': StateValue(val=1.0, idx=14157), 'health': StateValue(val=1.0, idx=14161), 'theta': StateValue(val=-100.0, idx=14165), 'grow_rate': StateValue(val=1.0, idx=14169), 'alpha_decay': StateValue(val=1.0, idx=14173), 'climber_spawn_x': StateValue(val=0.0, idx=14177)}]
# []
# ...
# Warning: Buffer underflow at index 21376 with size 4, buffer length 21376. Returning default value.
# Warning: Buffer underflow at index 21376 with size 4, buffer length 21376. Returning default value.
# Warning: Buffer underflow at index 21376 with size 4, buffer length 21376. Returning default value.
# []
# Warning: Buffer underflow at index 21261 with size 4, buffer length 21261. Returning default value.
# Warning: Buffer underflow at index 21261 with size 4, buffer length 21261. Returning default value.
# Warning: Buffer underflow at index 21261 with size 4, buffer length 21261. Returning default value.
# []
# Warning: Buffer underflow at index 21136 with size 4, buffer length 21136. Returning default value.
# Warning: Buffer underflow at index 21136 with size 4, buffer length 21136. Returning default value.
# Warning: Buffer underflow at index 21136 with size 4, buffer length 21136. Returning default value.
# []
# Warning: Buffer underflow at index 21227 with size 4, buffer length 21227. Returning default value.
# Warning: Buffer underflow at index 21227 with size 4, buffer length 21227. Returning default value.
# Warning: Buffer underflow at index 21227 with size 4, buffer length 21227. Returning default value.
# []
# Warning: Buffer underflow at index 21392 with size 4, buffer length 21392. Returning default value.
# Warning: Buffer underflow at index 21392 with size 4, buffer length 21392. Returning default value.
# Warning: Buffer underflow at index 21392 with size 4, buffer length 21392. Returning default value.
# []
# [{'x': StateValue(val=2.5, idx=13815), 'y': StateValue(val=2.5, idx=13819), 'vx': StateValue(val=0.0, idx=13823), 'vy': StateValue(val=0.0, idx=13827), 'rx': StateValue(val=0.5, idx=13831), 'ry': StateValue(val=0.5, idx=13835), 'type': StateValue(val=1, idx=13839), 'image_type': StateValue(val=1, idx=13843), 'image_theme': StateValue(val=1, idx=13847), 'render_z': StateValue(val=0, idx=13851), 'will_erase': StateValue(val=0, idx=13855), 'collides_with_entities': StateValue(val=0, idx=13859), 'collision_margin': StateValue(val=0.0, idx=13863), 'rotation': StateValue(val=0.0, idx=13867), 'vrot': StateValue(val=0.0, idx=13871), 'is_reflected': StateValue(val=0, idx=13875), 'fire_time': StateValue(val=-1, idx=13879), 'spawn_time': StateValue(val=-1, idx=13883), 'life_time': StateValue(val=0, idx=13887), 'expire_time': StateValue(val=-1, idx=13891), 'use_abs_coords': StateValue(val=0, idx=13895), 'friction': StateValue(val=1.0, idx=13899), 'smart_step': StateValue(val=0, idx=13903), 'avoids_collisions': StateValue(val=0, idx=13907), 'auto_erase': StateValue(val=1, idx=13911), 'alpha': StateValue(val=1.0, idx=13915), 'health': StateValue(val=1.0, idx=13919), 'theta': StateValue(val=-100.0, idx=13923), 'grow_rate': StateValue(val=1.0, idx=13927), 'alpha_decay': StateValue(val=1.0, idx=13931), 'climber_spawn_x': StateValue(val=0.0, idx=13935)}, {'x': StateValue(val=4.5, idx=14063), 'y': StateValue(val=2.5, idx=14067), 'vx': StateValue(val=0.0, idx=14071), 'vy': StateValue(val=0.0, idx=14075), 'rx': StateValue(val=0.5, idx=14079), 'ry': StateValue(val=0.5, idx=14083), 'type': StateValue(val=1, idx=14087), 'image_type': StateValue(val=1, idx=14091), 'image_theme': StateValue(val=0, idx=14095), 'render_z': StateValue(val=0, idx=14099), 'will_erase': StateValue(val=0, idx=14103), 'collides_with_entities': StateValue(val=0, idx=14107), 'collision_margin': StateValue(val=0.0, idx=14111), 'rotation': StateValue(val=0.0, idx=14115), 'vrot': StateValue(val=0.0, idx=14119), 'is_reflected': StateValue(val=0, idx=14123), 'fire_time': StateValue(val=-1, idx=14127), 'spawn_time': StateValue(val=-1, idx=14131), 'life_time': StateValue(val=0, idx=14135), 'expire_time': StateValue(val=-1, idx=14139), 'use_abs_coords': StateValue(val=0, idx=14143), 'friction': StateValue(val=1.0, idx=14147), 'smart_step': StateValue(val=0, idx=14151), 'avoids_collisions': StateValue(val=0, idx=14155), 'auto_erase': StateValue(val=1, idx=14159), 'alpha': StateValue(val=1.0, idx=14163), 'health': StateValue(val=1.0, idx=14167), 'theta': StateValue(val=-100.0, idx=14171), 'grow_rate': StateValue(val=1.0, idx=14175), 'alpha_decay': StateValue(val=1.0, idx=14179), 'climber_spawn_x': StateValue(val=0.0, idx=14183)}, {'x': StateValue(val=6.5, idx=14311), 'y': StateValue(val=2.5, idx=14315), 'vx': StateValue(val=0.0, idx=14319), 'vy': StateValue(val=0.0, idx=14323), 'rx': StateValue(val=0.5, idx=14327), 'ry': StateValue(val=0.5, idx=14331), 'type': StateValue(val=1, idx=14335), 'image_type': StateValue(val=1, idx=14339), 'image_theme': StateValue(val=2, idx=14343), 'render_z': StateValue(val=0, idx=14347), 'will_erase': StateValue(val=0, idx=14351), 'collides_with_entities': StateValue(val=0, idx=14355), 'collision_margin': StateValue(val=0.0, idx=14359), 'rotation': StateValue(val=0.0, idx=14363), 'vrot': StateValue(val=0.0, idx=14367), 'is_reflected': StateValue(val=0, idx=14371), 'fire_time': StateValue(val=-1, idx=14375), 'spawn_time': StateValue(val=-1, idx=14379), 'life_time': StateValue(val=0, idx=14383), 'expire_time': StateValue(val=-1, idx=14387), 'use_abs_coords': StateValue(val=0, idx=14391), 'friction': StateValue(val=1.0, idx=14395), 'smart_step': StateValue(val=0, idx=14399), 'avoids_collisions': StateValue(val=0, idx=14403), 'auto_erase': StateValue(val=1, idx=14407), 'alpha': StateValue(val=1.0, idx=14411), 'health': StateValue(val=1.0, idx=14415), 'theta': StateValue(val=-100.0, idx=14419), 'grow_rate': StateValue(val=1.0, idx=14423), 'alpha_decay': StateValu ...
# [{'x': StateValue(val=0.5, idx=13818), 'y': StateValue(val=6.5, idx=13822), 'vx': StateValue(val=0.0, idx=13826), 'vy': StateValue(val=0.0, idx=13830), 'rx': StateValue(val=0.5, idx=13834), 'ry': StateValue(val=0.5, idx=13838), 'type': StateValue(val=1, idx=13842), 'image_type': StateValue(val=1, idx=13846), 'image_theme': StateValue(val=1, idx=13850), 'render_z': StateValue(val=0, idx=13854), 'will_erase': StateValue(val=0, idx=13858), 'collides_with_entities': StateValue(val=0, idx=13862), 'collision_margin': StateValue(val=0.0, idx=13866), 'rotation': StateValue(val=0.0, idx=13870), 'vrot': StateValue(val=0.0, idx=13874), 'is_reflected': StateValue(val=0, idx=13878), 'fire_time': StateValue(val=-1, idx=13882), 'spawn_time': StateValue(val=-1, idx=13886), 'life_time': StateValue(val=0, idx=13890), 'expire_time': StateValue(val=-1, idx=13894), 'use_abs_coords': StateValue(val=0, idx=13898), 'friction': StateValue(val=1.0, idx=13902), 'smart_step': StateValue(val=0, idx=13906), 'avoids_collisions': StateValue(val=0, idx=13910), 'auto_erase': StateValue(val=1, idx=13914), 'alpha': StateValue(val=1.0, idx=13918), 'health': StateValue(val=1.0, idx=13922), 'theta': StateValue(val=-100.0, idx=13926), 'grow_rate': StateValue(val=1.0, idx=13930), 'alpha_decay': StateValue(val=1.0, idx=13934), 'climber_spawn_x': StateValue(val=0.0, idx=13938)}, {'x': StateValue(val=4.5, idx=14066), 'y': StateValue(val=4.5, idx=14070), 'vx': StateValue(val=0.0, idx=14074), 'vy': StateValue(val=0.0, idx=14078), 'rx': StateValue(val=0.5, idx=14082), 'ry': StateValue(val=0.5, idx=14086), 'type': StateValue(val=1, idx=14090), 'image_type': StateValue(val=1, idx=14094), 'image_theme': StateValue(val=0, idx=14098), 'render_z': StateValue(val=0, idx=14102), 'will_erase': StateValue(val=0, idx=14106), 'collides_with_entities': StateValue(val=0, idx=14110), 'collision_margin': StateValue(val=0.0, idx=14114), 'rotation': StateValue(val=0.0, idx=14118), 'vrot': StateValue(val=0.0, idx=14122), 'is_reflected': StateValue(val=0, idx=14126), 'fire_time': StateValue(val=-1, idx=14130), 'spawn_time': StateValue(val=-1, idx=14134), 'life_time': StateValue(val=0, idx=14138), 'expire_time': StateValue(val=-1, idx=14142), 'use_abs_coords': StateValue(val=0, idx=14146), 'friction': StateValue(val=1.0, idx=14150), 'smart_step': StateValue(val=0, idx=14154), 'avoids_collisions': StateValue(val=0, idx=14158), 'auto_erase': StateValue(val=1, idx=14162), 'alpha': StateValue(val=1.0, idx=14166), 'health': StateValue(val=1.0, idx=14170), 'theta': StateValue(val=-100.0, idx=14174), 'grow_rate': StateValue(val=1.0, idx=14178), 'alpha_decay': StateValue(val=1.0, idx=14182), 'climber_spawn_x': StateValue(val=0.0, idx=14186)}]
# [{'x': StateValue(val=5.5, idx=13839), 'y': StateValue(val=5.5, idx=13843), 'vx': StateValue(val=0.0, idx=13847), 'vy': StateValue(val=0.0, idx=13851), 'rx': StateValue(val=0.5, idx=13855), 'ry': StateValue(val=0.5, idx=13859), 'type': StateValue(val=1, idx=13863), 'image_type': StateValue(val=1, idx=13867), 'image_theme': StateValue(val=0, idx=13871), 'render_z': StateValue(val=0, idx=13875), 'will_erase': StateValue(val=0, idx=13879), 'collides_with_entities': StateValue(val=0, idx=13883), 'collision_margin': StateValue(val=0.0, idx=13887), 'rotation': StateValue(val=0.0, idx=13891), 'vrot': StateValue(val=0.0, idx=13895), 'is_reflected': StateValue(val=0, idx=13899), 'fire_time': StateValue(val=-1, idx=13903), 'spawn_time': StateValue(val=-1, idx=13907), 'life_time': StateValue(val=0, idx=13911), 'expire_time': StateValue(val=-1, idx=13915), 'use_abs_coords': StateValue(val=0, idx=13919), 'friction': StateValue(val=1.0, idx=13923), 'smart_step': StateValue(val=0, idx=13927), 'avoids_collisions': StateValue(val=0, idx=13931), 'auto_erase': StateValue(val=1, idx=13935), 'alpha': StateValue(val=1.0, idx=13939), 'health': StateValue(val=1.0, idx=13943), 'theta': StateValue(val=-100.0, idx=13947), 'grow_rate': StateValue(val=1.0, idx=13951), 'alpha_decay': StateValue(val=1.0, idx=13955), 'climber_spawn_x': StateValue(val=0.0, idx=13959)}]
# Warning: Buffer underflow at index 21369 with size 4, buffer length 21369. Returning default value.
# Warning: Buffer underflow at index 21369 with size 4, buffer length 21369. Returning default value.
# Warning: Buffer underflow at index 21369 with size 4, buffer length 21369. Returning default value.
# []
# Warning: Buffer underflow at index 21121 with size 4, buffer length 21121. Returning default value.
# Warning: Buffer underflow at index 21121 with size 4, buffer length 21121. Returning default value.
# Warning: Buffer underflow at index 21121 with size 4, buffer length 21121. Returning default value.
# []
# [{'x': StateValue(val=0.5, idx=13699), 'y': StateValue(val=4.5, idx=13703), 'vx': StateValue(val=0.0, idx=13707), 'vy': StateValue(val=0.0, idx=13711), 'rx': StateValue(val=0.5, idx=13715), 'ry': StateValue(val=0.5, idx=13719), 'type': StateValue(val=1, idx=13723), 'image_type': StateValue(val=1, idx=13727), 'image_theme': StateValue(val=0, idx=13731), 'render_z': StateValue(val=0, idx=13735), 'will_erase': StateValue(val=0, idx=13739), 'collides_with_entities': StateValue(val=0, idx=13743), 'collision_margin': StateValue(val=0.0, idx=13747), 'rotation': StateValue(val=0.0, idx=13751), 'vrot': StateValue(val=0.0, idx=13755), 'is_reflected': StateValue(val=0, idx=13759), 'fire_time': StateValue(val=-1, idx=13763), 'spawn_time': StateValue(val=-1, idx=13767), 'life_time': StateValue(val=0, idx=13771), 'expire_time': StateValue(val=-1, idx=13775), 'use_abs_coords': StateValue(val=0, idx=13779), 'friction': StateValue(val=1.0, idx=13783), 'smart_step': StateValue(val=0, idx=13787), 'avoids_collisions': StateValue(val=0, idx=13791), 'auto_erase': StateValue(val=1, idx=13795), 'alpha': StateValue(val=1.0, idx=13799), 'health': StateValue(val=1.0, idx=13803), 'theta': StateValue(val=-100.0, idx=13807), 'grow_rate': StateValue(val=1.0, idx=13811), 'alpha_decay': StateValue(val=1.0, idx=13815), 'climber_spawn_x': StateValue(val=0.0, idx=13819)}, {'x': StateValue(val=2.5, idx=13947), 'y': StateValue(val=6.5, idx=13951), 'vx': StateValue(val=0.0, idx=13955), 'vy': StateValue(val=0.0, idx=13959), 'rx': StateValue(val=0.5, idx=13963), 'ry': StateValue(val=0.5, idx=13967), 'type': StateValue(val=1, idx=13971), 'image_type': StateValue(val=1, idx=13975), 'image_theme': StateValue(val=1, idx=13979), 'render_z': StateValue(val=0, idx=13983), 'will_erase': StateValue(val=0, idx=13987), 'collides_with_entities': StateValue(val=0, idx=13991), 'collision_margin': StateValue(val=0.0, idx=13995), 'rotation': StateValue(val=0.0, idx=13999), 'vrot': StateValue(val=0.0, idx=14003), 'is_reflected': StateValue(val=0, idx=14007), 'fire_time': StateValue(val=-1, idx=14011), 'spawn_time': StateValue(val=-1, idx=14015), 'life_time': StateValue(val=0, idx=14019), 'expire_time': StateValue(val=-1, idx=14023), 'use_abs_coords': StateValue(val=0, idx=14027), 'friction': StateValue(val=1.0, idx=14031), 'smart_step': StateValue(val=0, idx=14035), 'avoids_collisions': StateValue(val=0, idx=14039), 'auto_erase': StateValue(val=1, idx=14043), 'alpha': StateValue(val=1.0, idx=14047), 'health': StateValue(val=1.0, idx=14051), 'theta': StateValue(val=-100.0, idx=14055), 'grow_rate': StateValue(val=1.0, idx=14059), 'alpha_decay': StateValue(val=1.0, idx=14063), 'climber_spawn_x': StateValue(val=0.0, idx=14067)}]
# Warning: Buffer underflow at index 21368 with size 4, buffer length 21368. Returning default value.
# Warning: Buffer underflow at index 21368 with size 4, buffer length 21368. Returning default value.
# Warning: Buffer underflow at index 21368 with size 4, buffer length 21368. Returning default value.
# []
# []
# []
# []
# Warning: Buffer underflow at index 21105 with size 4, buffer length 21105. Returning default value.
# Warning: Buffer underflow at index 21105 with size 4, buffer length 21105. Returning default value.
# Warning: Buffer underflow at index 21105 with size 4, buffer length 21105. Returning default value.
# []
